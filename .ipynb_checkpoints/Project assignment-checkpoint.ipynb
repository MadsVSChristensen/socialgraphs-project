# %%
import urllib.request
import json
import gzip
import shutil
import re
from collections import Counter
import matplotlib.pylab as plt
import numpy as np
import networkx as nx
from fa2 import ForceAtlas2
import community

# %% [markdown]
# First of all we need data about Stack Overflow questions, retrieved from Stack Exchange. We go back 10 years with 100 questions each month for a total of 12000 questions.

# %%
#list of jsons
jsons = []

#All tags w. duplicates
allTags = []

#List of lists. Each year is a list inside.
yearList = []


# variables
oneYear=86400*365
halfMonth=int((oneYear/12)/2)
todate=1572998400
fromdate=todate-halfmonth

# 10 years back
for i in range(1,11):
    #print("i",i)
    year = []
    #Each month
    for ii in range (1,13):
        #print("ii", ii)
        #print("todate",todate,"fromdate",fromdate)
        #Query for stackexchange
        query = "https://api.stackexchange.com//2.2/questions?pagesize=100&fromdate={}&todate={}&order=desc&sort=votes&site=stackoverflow&filter=!9Z(-wwK0y".format(fromdate,todate)
        response = urllib.request.urlopen(query)
        gzipFile = gzip.GzipFile(fileobj=response)
        src = gzipFile.read()
        stackjson = json.loads(src)
        #save json
        jsons.append(stackjson)
        #get each tag and save it 
        for question in stackjson['items']:
            #remove duplicate from tags after a trimming (['c', 'c-v12.1']) trim-> (['c', 'c']) remove-> (['c'])
            taglist = [re.sub(r"(-)*(\d)+(\..)*","",tag) for tag in question['tags']]
            allTags.extend(list(dict.fromkeys(taglist)))
            year.extend(list(dict.fromkeys(taglist)))
        todate-=halfmonth
        fromdate-=halfmonth
    yearList.append(year)
# Out:
# i 1
# ii 1
# todate 1572998400 fromdate 1570370400
# ii 2
# todate 1570370400 fromdate 1567742400
# ii 3
# todate 1567742400 fromdate 1565114400
# ii 4
# todate 1565114400 fromdate 1562486400
# ii 5
# todate 1562486400 fromdate 1559858400
# ii 6
# todate 1559858400 fromdate 1557230400
# ii 7
# todate 1557230400 fromdate 1554602400
# ii 8
# todate 1554602400 fromdate 1551974400
# ii 9
# todate 1551974400 fromdate 1549346400
# ii 10
# todate 1549346400 fromdate 1546718400
# ii 11
# todate 1546718400 fromdate 1544090400
# ii 12
# todate 1544090400 fromdate 1541462400
# i 2
# ii 1
# todate 1541462400 fromdate 1538834400
# ii 2
# todate 1538834400 fromdate 1536206400
# ii 3
# todate 1536206400 fromdate 1533578400
# ii 4
# todate 1533578400 fromdate 1530950400
# ii 5
# todate 1530950400 fromdate 1528322400
# ii 6
# todate 1528322400 fromdate 1525694400
# ii 7
# todate 1525694400 fromdate 1523066400
# ii 8
# todate 1523066400 fromdate 1520438400
# ii 9
# todate 1520438400 fromdate 1517810400
# ii 10
# todate 1517810400 fromdate 1515182400
# ii 11
# todate 1515182400 fromdate 1512554400
# ii 12
# todate 1512554400 fromdate 1509926400
# i 3
# ii 1
# todate 1509926400 fromdate 1507298400
# ii 2
# todate 1507298400 fromdate 1504670400
# ii 3
# todate 1504670400 fromdate 1502042400
# ii 4
# todate 1502042400 fromdate 1499414400
# ii 5
# todate 1499414400 fromdate 1496786400
# ii 6
# todate 1496786400 fromdate 1494158400
# ii 7
# todate 1494158400 fromdate 1491530400
# ii 8
# todate 1491530400 fromdate 1488902400
# ii 9
# todate 1488902400 fromdate 1486274400
# ii 10
# todate 1486274400 fromdate 1483646400
# ii 11
# todate 1483646400 fromdate 1481018400
# ii 12
# todate 1481018400 fromdate 1478390400
# i 4
# ii 1
# todate 1478390400 fromdate 1475762400
# ii 2
# todate 1475762400 fromdate 1473134400
# ii 3
# todate 1473134400 fromdate 1470506400
# ii 4
# todate 1470506400 fromdate 1467878400
# ii 5
# todate 1467878400 fromdate 1465250400
# ii 6
# todate 1465250400 fromdate 1462622400
# ii 7
# todate 1462622400 fromdate 1459994400
# ii 8
# todate 1459994400 fromdate 1457366400
# ii 9
# todate 1457366400 fromdate 1454738400
# ii 10
# todate 1454738400 fromdate 1452110400
# ii 11
# todate 1452110400 fromdate 1449482400
# ii 12
# todate 1449482400 fromdate 1446854400
# i 5
# ii 1
# todate 1446854400 fromdate 1444226400
# ii 2
# todate 1444226400 fromdate 1441598400
# ii 3
# todate 1441598400 fromdate 1438970400
# ii 4
# todate 1438970400 fromdate 1436342400
# ii 5
# todate 1436342400 fromdate 1433714400
# ii 6
# todate 1433714400 fromdate 1431086400
# ii 7
# todate 1431086400 fromdate 1428458400
# ii 8
# todate 1428458400 fromdate 1425830400
# ii 9
# todate 1425830400 fromdate 1423202400
# ii 10
# todate 1423202400 fromdate 1420574400
# ii 11
# todate 1420574400 fromdate 1417946400
# ii 12
# todate 1417946400 fromdate 1415318400
# i 6
# ii 1
# todate 1415318400 fromdate 1412690400
# ii 2
# todate 1412690400 fromdate 1410062400
# ii 3
# todate 1410062400 fromdate 1407434400
# ii 4
# todate 1407434400 fromdate 1404806400
# ii 5
# todate 1404806400 fromdate 1402178400
# ii 6
# todate 1402178400 fromdate 1399550400
# ii 7
# todate 1399550400 fromdate 1396922400
# ii 8
# todate 1396922400 fromdate 1394294400
# ii 9
# todate 1394294400 fromdate 1391666400
# ii 10
# todate 1391666400 fromdate 1389038400
# ii 11
# todate 1389038400 fromdate 1386410400
# ii 12
# todate 1386410400 fromdate 1383782400
# i 7
# ii 1
# todate 1383782400 fromdate 1381154400
# ii 2
# todate 1381154400 fromdate 1378526400
# ii 3
# todate 1378526400 fromdate 1375898400
# ii 4
# todate 1375898400 fromdate 1373270400
# ii 5
# todate 1373270400 fromdate 1370642400
# ii 6
# todate 1370642400 fromdate 1368014400
# ii 7
# todate 1368014400 fromdate 1365386400
# ii 8
# todate 1365386400 fromdate 1362758400
# ii 9
# todate 1362758400 fromdate 1360130400
# ii 10
# todate 1360130400 fromdate 1357502400
# ii 11
# todate 1357502400 fromdate 1354874400
# ii 12
# todate 1354874400 fromdate 1352246400
# i 8
# ii 1
# todate 1352246400 fromdate 1349618400
# ii 2
# todate 1349618400 fromdate 1346990400
# ii 3
# todate 1346990400 fromdate 1344362400
# ii 4
# todate 1344362400 fromdate 1341734400
# ii 5
# todate 1341734400 fromdate 1339106400
# ii 6
# todate 1339106400 fromdate 1336478400
# ii 7
# todate 1336478400 fromdate 1333850400
# ii 8
# todate 1333850400 fromdate 1331222400
# ii 9
# todate 1331222400 fromdate 1328594400
# ii 10
# todate 1328594400 fromdate 1325966400
# ii 11
# todate 1325966400 fromdate 1323338400
# ii 12
# todate 1323338400 fromdate 1320710400
# i 9
# ii 1
# todate 1320710400 fromdate 1318082400
# ii 2
# todate 1318082400 fromdate 1315454400
# ii 3
# todate 1315454400 fromdate 1312826400
# ii 4
# todate 1312826400 fromdate 1310198400
# ii 5
# todate 1310198400 fromdate 1307570400
# ii 6
# todate 1307570400 fromdate 1304942400
# ii 7
# todate 1304942400 fromdate 1302314400
# ii 8
# todate 1302314400 fromdate 1299686400
# ii 9
# todate 1299686400 fromdate 1297058400
# ii 10
# todate 1297058400 fromdate 1294430400
# ii 11
# todate 1294430400 fromdate 1291802400
# ii 12
# todate 1291802400 fromdate 1289174400
# i 10
# ii 1
# todate 1289174400 fromdate 1286546400
# ii 2
# todate 1286546400 fromdate 1283918400
# ii 3
# todate 1283918400 fromdate 1281290400
# ii 4
# todate 1281290400 fromdate 1278662400
# ii 5
# todate 1278662400 fromdate 1276034400
# ii 6
# todate 1276034400 fromdate 1273406400
# ii 7
# todate 1273406400 fromdate 1270778400
# ii 8
# todate 1270778400 fromdate 1268150400
# ii 9
# todate 1268150400 fromdate 1265522400
# ii 10
# todate 1265522400 fromdate 1262894400
# ii 11
# todate 1262894400 fromdate 1260266400
# ii 12
# todate 1260266400 fromdate 1257638400

# %%
# Counter dictionary for all tags
tagDict = Counter(allTags)
print("Number of unique: ",len(list(tagDict.keys())))
print("Number of tags from all questions: ", len(allTags))
# Out:
# Number of unique:  4689
# Number of tags from all questions:  35883

# %% [markdown]
# First we wish to find the most popular subjects on Stack Overflow. We do this by taking each questions tags and grouping them together. Here we count the number of occurences and we find the following results:

# %%
# Sort tags by number of occurences
sorted_x = sorted(tagDict.items(), key=lambda kv: kv[1], reverse=True)
n_items = sorted_x[0:20]
x, y = zip(*n_items) # unpack a list of pairs into two tuples
plt.figure(figsize=(20,5))
plt.bar(x, y)
plt.xticks(rotation=50)
plt.show()

# %% [markdown]
# There is a very clear top 4, and an even more clear winner; Javascript. Javascript appears approximately 1400 times in the 12000, meaning 12% of all questions are about Javascript. Interestingly android has twice the number of tags of ios, finally settling the debate about which is the most popular mobile operating system. However, this is more likely due to android being easier accessible to new programmers.

# %% [markdown]
# But how have these subjects popularity developed over time? We investigate the 6 most popular tags of all time, and see their development through the last 10 years.

# %%
#Tags per year
tags2019 = yearList[0]
tags2018 = yearList[1]
tags2017 = yearList[2]
tags2016 = yearList[3] 
tags2015 = yearList[4]
tags2014 = yearList[5]
tags2013 = yearList[6]
tags2012 = yearList[7]
tags2011 = yearList[8]
tags2010 = yearList[9]

#Dict pr. year
tags2019dict = Counter(tags2019)
tags2018dict = Counter(tags2018)
tags2017dict = Counter(tags2017)
tags2016dict = Counter(tags2016)
tags2015dict = Counter(tags2015)
tags2014dict = Counter(tags2014)
tags2013dict = Counter(tags2013)
tags2012dict = Counter(tags2012)
tags2011dict = Counter(tags2011)
tags2010dict = Counter(tags2010)

# %%
plt.figure(figsize=(20,10))

# set width of bar
barWidth = 0.15

# x-values for the plots
barsWord1 = [tags2019dict[x[0]], tags2018dict[x[0]], tags2017dict[x[0]], tags2016dict[x[0]], tags2015dict[x[0]], tags2014dict[x[0]], tags2013dict[x[0]], tags2012dict[x[0]], tags2011dict[x[0]],tags2010dict[x[0]]]
barsWord2 = [tags2019dict[x[1]], tags2018dict[x[1]], tags2017dict[x[1]], tags2016dict[x[1]], tags2015dict[x[1]], tags2014dict[x[1]], tags2013dict[x[1]], tags2012dict[x[1]], tags2011dict[x[1]],tags2010dict[x[1]]]
barsWord3 = [tags2019dict[x[2]], tags2018dict[x[2]], tags2017dict[x[2]], tags2016dict[x[2]], tags2015dict[x[2]], tags2014dict[x[2]], tags2013dict[x[2]], tags2012dict[x[2]], tags2011dict[x[2]],tags2010dict[x[2]]]
barsWord4 = [tags2019dict[x[3]], tags2018dict[x[3]], tags2017dict[x[3]], tags2016dict[x[3]], tags2015dict[x[3]], tags2014dict[x[3]], tags2013dict[x[3]], tags2012dict[x[3]], tags2011dict[x[3]],tags2010dict[x[3]]]
barsWord5 = [tags2019dict[x[4]], tags2018dict[x[4]], tags2017dict[x[4]], tags2016dict[x[4]], tags2015dict[x[4]], tags2014dict[x[4]], tags2013dict[x[4]], tags2012dict[x[4]], tags2011dict[x[4]],tags2010dict[x[4]]]
barsWord6 = [tags2019dict[x[5]], tags2018dict[x[5]], tags2017dict[x[5]], tags2016dict[x[5]], tags2015dict[x[5]], tags2014dict[x[5]], tags2013dict[x[5]], tags2012dict[x[5]], tags2011dict[x[5]],tags2010dict[x[5]]]


# Set position of bar on X axis
r1 = np.arange(len(barsWord1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]
r6 = [x + barWidth for x in r5]

 
# Make the plot
plt.bar(r1, barsWord1, color='#FF2D00', width=barWidth, edgecolor='white', label=x[0])
plt.bar(r2, barsWord2, color='#FFDC00', width=barWidth, edgecolor='white', label=x[1])
plt.bar(r3, barsWord3, color='#18FF00', width=barWidth, edgecolor='white', label=x[2])
plt.bar(r4, barsWord4, color='#003CFF', width=barWidth, edgecolor='white', label=x[3])
plt.bar(r5, barsWord5, color='#9E09DA', width=barWidth, edgecolor='white', label=x[4])
plt.bar(r6, barsWord6, color='#000000', width=barWidth, edgecolor='white', label=x[5])

 
# Add xticks on the middle of the group bars
plt.xlabel('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(barsWord1))], ['2019','2018','2017','2016','2015','2014','2013','2012','2011','2010'])
 
# Create legend & Show graphic
plt.legend()
plt.show()

# %% [markdown]
# As can be seen from the bar plot, most of the tags fluctuate quite a bit. Especially c++ which tripples its amount of occurences in 2019. C++ has seen a resurgance the last few years(footnote 1), but unfortunately nothing explains a development this wild. This is likely due to a random outlier in our data, even if we have 3600 tags from 2019.
#
# We also se python increase in popularity, this correlates well with the trend seen in larger datasets and analyses (see footnote 1 on the website).

# %% [markdown]
# Just to show that our data does infact portray the real world we show you reactjs' development throught the last 10 years.

# %%
# Plot for reactjs
barsreact = [tags2019dict['reactjs'], tags2018dict['reactjs'], tags2017dict['reactjs'], tags2016dict['reactjs'], tags2015dict['reactjs'], tags2014dict['reactjs'], tags2013dict['reactjs'], tags2012dict['reactjs'], tags2011dict['reactjs'],tags2010dict['reactjs']]

plt.figure(figsize=(20,10))
plt.bar(['2019','2018','2017','2016','2015','2014','2013','2012','2011','2010'],barsreact)
plt.show()

# %% [markdown]
# As you may have guessed from the bar plot, reactjs was launched in 2013 by Facebook and has since quickly gained a lot of popularity.

# %% [markdown]
# Each question has one or more tags, where you can tag more subjects if your questions has correlation to more than one subject. We want to see which tags are well connected and which groups of tags may appear.
#
# So we create a network of all the tags, and all edges between nodes whenever two or more tags have been tagged together in a question. We assume this means they have a sort of correlation, and give this attribute an edge.
#
# Ex. `(['reacjs', 'nodejs', 'javascript']) -> [(reactjs---nodejs), (reactjs---javascript), (nodejs---javascript)]`.
# Edges is denoted by `---`.

# %%
network = nx.Graph()
network.add_nodes_from(list(dict.fromkeys(allTags)))
# Because we have to work on each questions tag-list, we have to use the saved jsons.
for json in jsons:
    for question in json['items']:
        # trimming of tags
        taglisthelper = [re.sub(r"(-)*(\d)+(\..)*","",tag) for tag in question['tags']]
        # remove duplicates
        taglisthelper = list(dict.fromkeys(taglisthelper))
        for tag in taglisthelper:
            for tag2 in taglisthelper:
                network.add_edge(tag,tag2)
# Out:
# ['ios', 'swift', 'xcode', 'uitextview', 'xcode']
# ['ios', 'swift', 'xcode', 'uitextview']
# ['bash', 'git', 'macos', 'zsh', 'macos-catalina']
# ['bash', 'git', 'macos', 'zsh', 'macos-catalina']
# ['xcode', 'macos', 'macos-catalina']
# ['xcode', 'macos', 'macos-catalina']
# ['c', 'scanf']
# ['c', 'scanf']
# ['python', 'boolean-logic']
# ['python', 'boolean-logic']
# ['c', 'linux', 'assembly', 'mmap']
# ['c', 'linux', 'assembly', 'mmap']
# ['python', 'tensorflow', 'keras', 'performance-testing', 'tensorflow']
# ['python', 'tensorflow', 'keras', 'performance-testing']
# ['ios', 'objective-c', 'wkwebview']
# ['ios', 'objective-c', 'wkwebview']
# ['c++', 'assembly', 'unique-ptr', 'calling-convention', 'abi']
# ['c++', 'assembly', 'unique-ptr', 'calling-convention', 'abi']
# ['android', 'cordova', 'ionic-framework', 'ionic', 'build.gradle']
# ['android', 'cordova', 'ionic-framework', 'ionic', 'build.gradle']
# ['python', 'python', 'list', 'tuples']
# ['python', 'list', 'tuples']
# ['ruby', 'floating-point', 'negative-zero']
# ['ruby', 'floating-point', 'negative-zero']
# ['c++', 'multithreading', 'thread-safety', 'data-race']
# ['c++', 'multithreading', 'thread-safety', 'data-race']
# ['javascript', 'google-chrome', 'cookies', 'samesite']
# ['javascript', 'google-chrome', 'cookies', 'samesite']
# ['ios', 'swift', 'xcode', 'swift']
# ['ios', 'swift', 'xcode']
# ['c++', 'visual-c++']
# ['c++', 'visual-c++']
# ['java']
# ['java']
# ['c#', '.net', 'datetime', '.net-core', 'datetime-format']
# ['c#', '.net', 'datetime', '.net-core', 'datetime-format']
# ['java', 'string', 'while-loop', 'jvm', 'jit']
# ['java', 'string', 'while-loop', 'jvm', 'jit']
# ['python', 'haskell', 'functional-programming', 'partial-application', 'partial-functions']
# ['python', 'haskell', 'functional-programming', 'partial-application', 'partial-functions']
# ['python', 'recursion']
# ['python', 'recursion']
# ['xcode', 'xcode', 'macos-catalina', 'xcode', 'xcode']
# ['xcode', 'macos-catalina']
# ['haskell', 'functional-programming']
# ['haskell', 'functional-programming']
# ['mongodb', 'macos']
# ['mongodb', 'macos']
# ['c', 'xcode', 'macos', 'gcc', 'macos-catalina']
# ['c', 'xcode', 'macos', 'gcc', 'macos-catalina']
# ['java', 'generics', 'lambda', 'type-inference', 'method-reference']
# ['java', 'generics', 'lambda', 'type-inference', 'method-reference']
# ['macos', 'visual-studio-code', 'macos-catalina']
# ['macos', 'visual-studio-code', 'macos-catalina']
# ['ios', 'swift', 'uinavigationcontroller', 'swiftui', 'xcode']
# ['ios', 'swift', 'uinavigationcontroller', 'swiftui', 'xcode']
# ['c++', 'pointers', 'undefined-behavior', 'dynamic-arrays']
# ['c++', 'pointers', 'undefined-behavior', 'dynamic-arrays']
# ['python', 'python', 'pip', 'python']
# ['python', 'pip']
# ['android', 'google-play', 'google-play-console']
# ['android', 'google-play', 'google-play-console']
# ['linux', 'bash', 'shell', 'io-redirection', 'proc-filesystem']
# ['linux', 'bash', 'shell', 'io-redirection', 'proc-filesystem']
# ['c++', 'stdstring', 'c++-standard-library']
# ['c++', 'stdstring', 'c++-standard-library']
# ['c++', 'c++']
# ['c++']
# ['python', 'pip', 'gekko']
# ['python', 'pip', 'gekko']
# ['c++', 'performance']
# ['c++', 'performance']
# ['c++', 'language-lawyer', 'object-lifetime', 'default-arguments', 'reference-binding']
# ['c++', 'language-lawyer', 'object-lifetime', 'default-arguments', 'reference-binding']
# ['python', 'oh-my-zsh', 'libcrypto', 'macos-catalina']
# ['python', 'oh-my-zsh', 'libcrypto', 'macos-catalina']
# ['c++', 'c', 'pointers', 'function-pointers', 'declaration']
# ['c++', 'c', 'pointers', 'function-pointers', 'declaration']
# ['ios', 'xcode']
# ['ios', 'xcode']
# ['c', 'pointers', 'undefined-behavior', 'memory-model', 'memory-segmentation']
# ['c', 'pointers', 'undefined-behavior', 'memory-model', 'memory-segmentation']
# ['c++', 'language-lawyer', 'volatile']
# ['c++', 'language-lawyer', 'volatile']
# ['google-chrome', 'tabs', 'popup', 'tooltip', 'updates']
# ['google-chrome', 'tabs', 'popup', 'tooltip', 'updates']
# ['python', 'pandas', 'dataframe', 'dictionary']
# ['python', 'pandas', 'dataframe', 'dictionary']
# ['c#', '.net-core']
# ['c#', '.net-core']
# ['python', 'python', 'anaconda', 'conda']
# ['python', 'anaconda', 'conda']
# ['python', 'list']
# ['python', 'list']
# ['xcode']
# ['xcode']
# ['java', 'java', 'type-promotion']
# ['java', 'type-promotion']
# ['python', 'windows', 'jupyter-notebook', 'tornado']
# ['python', 'windows', 'jupyter-notebook', 'tornado']
# ['java', 'default-value', 'instance-variables']
# ['java', 'default-value', 'instance-variables']
# ['c++', 'placement-new']
# ['c++', 'placement-new']
# ['perl', 'compilation']
# ['perl', 'compilation']
# ['python', 'python', 'python', 'python-requests']
# ['python', 'python-requests']
# ['laravel', 'macos', 'composer-php', 'macos-catalina']
# ['laravel', 'macos', 'composer-php', 'macos-catalina']
# ['java', 'java', 'java-stream']
# ['java', 'java-stream']
# ['java', 'type-inference']
# ['java', 'type-inference']
# ['python', 'reflection', 'overriding', 'subclass']
# ['python', 'reflection', 'overriding', 'subclass']
# ['html', 'css', 'acid']
# ['html', 'css', 'acid']
# ['google-chrome', 'cookies', 'samesite']
# ['google-chrome', 'cookies', 'samesite']
# ['python', 'testing', 'pytest', 'assert']
# ['python', 'testing', 'pytest', 'assert']
# ['ruby-on-rails', 'ruby-on-rails']
# ['ruby-on-rails']
# ['python', 'arrays', 'numpy', 'binning']
# ['python', 'arrays', 'numpy', 'binning']
# ['python', 'machine-learning', 'math', 'deep-learning', 'reinforcement-learning']
# ['python', 'machine-learning', 'math', 'deep-learning', 'reinforcement-learning']
# ['javascript', 'ios', 'xcode', 'react-native', 'instruments']
# ['javascript', 'ios', 'xcode', 'react-native', 'instruments']
# ['python', 'dictionary']
# ['python', 'dictionary']
# ['c++']
# ['c++']
# ['c++', 'c++', 'concept']
# ['c++', 'concept']
# ['typescript', 'typescript-generics']
# ['typescript', 'typescript-generics']
# ['c++', 'c++', 'constexpr', 'string-view']
# ['c++', 'constexpr', 'string-view']
# ['macos', 'anaconda', 'conda', 'environment', 'macos-catalina']
# ['macos', 'anaconda', 'conda', 'environment', 'macos-catalina']
# ['ios', 'xcode', 'macos', 'macos-catalina']
# ['ios', 'xcode', 'macos', 'macos-catalina']
# ['regex', 'ruby', 'boolean', 'jruby', 'yarv']
# ['regex', 'ruby', 'boolean', 'jruby', 'yarv']
# ['python', 'performance', 'tensorflow', 'keras', 'jupyter-notebook']
# ['python', 'performance', 'tensorflow', 'keras', 'jupyter-notebook']
# ['python', 'ubuntu', 'pip']
# ['python', 'ubuntu', 'pip']
# ['python', 'python', 'python-typing']
# ['python', 'python-typing']
# ['c++', 'undefined-behavior', 'c++', 'consteval']
# ['c++', 'undefined-behavior', 'consteval']
# ['c++', 'delete-operator']
# ['c++', 'delete-operator']
# ['python', 'pandas', 'coercion']
# ['python', 'pandas', 'coercion']
# ['haskell', 'functional-programming']
# ['haskell', 'functional-programming']
# ['java', 'selenium', 'selenium-webdriver', 'selenium-chromedriver']
# ['java', 'selenium', 'selenium-webdriver', 'selenium-chromedriver']
# ['javascript']
# ['javascript']
# ['ios', 'react-native', 'installation', 'pod', 'macos-catalina']
# ['ios', 'react-native', 'installation', 'pod', 'macos-catalina']
# ['scala', 'haskell', 'functional-programming', 'lenses', 'monocle-scala']
# ['scala', 'haskell', 'functional-programming', 'lenses', 'monocle-scala']
# ['python', 'pandas', 'numpy']
# ['python', 'pandas', 'numpy']
# ['python', 'pandas']
# ['python', 'pandas']
# ['javascript']
# ['javascript']
# ['c++', 'language-lawyer', 'undefined-behavior']
# ['c++', 'language-lawyer', 'undefined-behavior']
# ['c++', 'c++', 'type-punning']
# ['c++', 'type-punning']
# ['python', 'multithreading', 'threadpool', 'wait', 'future']
# ['python', 'multithreading', 'threadpool', 'wait', 'future']
# ['python', 'python', 'closures']
# ['python', 'closures']
# ['haskell']
# ['haskell']
# ['java', 'arrays', 'memory', 'memory-leaks']
# ['java', 'arrays', 'memory', 'memory-leaks']
# ['perl', 'oop', 'terminology']
# ['perl', 'oop', 'terminology']
# ['c++', 'templates']
# ['c++', 'templates']
# ['python', 'django', 'django-models']
# ['python', 'django', 'django-models']
# ['javascript']
# ['javascript']
# ['linux', 'linux-kernel', 'embedded-linux', 'splice', 'zero-copy']
# ['linux', 'linux-kernel', 'embedded-linux', 'splice', 'zero-copy']
# ['c++', 'c++']
# ['c++']
# ['c++', 'visual-studio', 'clang', 'c++', 'std']
# ['c++', 'visual-studio', 'clang', 'std']
# ['c++', 'c', 'warnings', 'compiler-warnings', 'c++-faq']
# ['c++', 'c', 'warnings', 'compiler-warnings', 'c++-faq']
# ['c']
# ['c']
# ['java', 'javac']
# ['java', 'javac']
# ['python', 'nan', 'ieee']
# ['python', 'nan', 'ieee']
# ['java', 'static', 'initialization', 'local-variables', 'jls']
# ['java', 'static', 'initialization', 'local-variables', 'jls']
# ['java', 'performance']
# ['java', 'performance']
# ['ios', 'xcode']
# ['ios', 'xcode']
# ['c++', 'for-loop', 'language-lawyer', 'c++']
# ['c++', 'for-loop', 'language-lawyer']
# ['reactjs', 'react-native', 'react-native-android', 'react-native-cli', 'metro-bundler']
# ['reactjs', 'react-native', 'react-native-android', 'react-native-cli', 'metro-bundler']
# ['yarnpkg']
# ['yarnpkg']
# ['c++', 'pointers', 'language-lawyer', 'c++', 'offsetof']
# ['c++', 'pointers', 'language-lawyer', 'offsetof']
# ['c++', 'templates', 'template-deduction', 'function-templates', 'argument-deduction']
# ['c++', 'templates', 'template-deduction', 'function-templates', 'argument-deduction']
# ['python', 'pytest']
# ['python', 'pytest']
# ['c++', 'constexpr', 'c++']
# ['c++', 'constexpr']
# ['xcode', 'phonegap-build', 'phonegap', 'xcode', 'application-loader']
# ['xcode', 'phonegap-build', 'phonegap', 'application-loader']
# ['c++', 'new-operator']
# ['c++', 'new-operator']
# ['c++', 'language-lawyer', 'lifetime', 'temporary', 'reference-binding']
# ['c++', 'language-lawyer', 'lifetime', 'temporary', 'reference-binding']
# ['c#', 'memory', 'lookup']
# ['c#', 'memory', 'lookup']
# ['ios', 'swift', 'xcode']
# ['ios', 'swift', 'xcode']
# ['ios', 'uinavigationcontroller', 'uisearchcontroller', 'ios']
# ['ios', 'uinavigationcontroller', 'uisearchcontroller']
# ['c', 'return-value', 'comma']
# ['c', 'return-value', 'comma']
# ['c++', 'copy-constructor', 'overload-resolution', 'function-templates', 'constructor-overloading']
# ['c++', 'copy-constructor', 'overload-resolution', 'function-templates', 'constructor-overloading']
# ['ios', 'testflight']
# ['ios', 'testflight']
# ['javascript', 'ios', 'safari', 'user-agent', 'ios']
# ['javascript', 'ios', 'safari', 'user-agent']
# ['c++', 'c', 'embedded', 'iar']
# ['c++', 'c', 'embedded', 'iar']
# ['c++', 'macos', 'shared-ptr', 'rvalue-reference']
# ['c++', 'macos', 'shared-ptr', 'rvalue-reference']
# ['c++', 'function', 'c++', 'templates', 'return-type']
# ['c++', 'function', 'templates', 'return-type']
# ['java', 'multithreading', 'race-condition']
# ['java', 'multithreading', 'race-condition']
# ['javascript', 'reactjs', 'react-hooks']
# ['javascript', 'reactjs', 'react-hooks']
# ['google-chrome', 'google-chrome-extension', 'google-chrome-devtools']
# ['google-chrome', 'google-chrome-extension', 'google-chrome-devtools']
# ['node.js', 'mongodb', 'mongoose']
# ['node.js', 'mongodb', 'mongoose']
# ['c++', 'c++', 'optional']
# ['c++', 'optional']
# ['c++', 'language-lawyer', 'c++', 'c++', 'order-of-execution']
# ['c++', 'language-lawyer', 'order-of-execution']
# ['javascript', 'arabic']
# ['javascript', 'arabic']
# ['python', 'interpreter', 'interpreted-language']
# ['python', 'interpreter', 'interpreted-language']
# ['python', 'dictionary', 'list-comprehension', 'itertools']
# ['python', 'dictionary', 'list-comprehension', 'itertools']
# ['c++', 'templates', 'inheritance']
# ['c++', 'templates', 'inheritance']
# ['python', 'algorithm', 'numpy', 'floating-point', 'sum']
# ['python', 'algorithm', 'numpy', 'floating-point', 'sum']
# ['c++', 'c++']
# ['c++']
# ['mongodb', 'macos', 'terminal']
# ['mongodb', 'macos', 'terminal']
# ['c++', 'c++', 'constinit']
# ['c++', 'constinit']
# ['android', 'android-studio', 'google-play-console', 'android-app-bundle']
# ['android', 'android-studio', 'google-play-console', 'android-app-bundle']
# ['php', 'cookies', 'google-chrome-extension']
# ['php', 'cookies', 'google-chrome-extension']
# ['javascript', 'ecmascript', 'arcgis', 'arcgis-js-api']
# ['javascript', 'ecmascript', 'arcgis', 'arcgis-js-api']
# ['javascript']
# ['javascript']
# ['ios', 'swift', 'xcode']
# ['ios', 'swift', 'xcode']
# ['c++', 'static-cast']
# ['c++', 'static-cast']
# ['scala', 'intellij-idea', 'sbt']
# ['scala', 'intellij-idea', 'sbt']
# ['haskell', 'set', 'coerce']
# ['haskell', 'set', 'coerce']
# ['javascript', 'google-chrome', 'websocket']
# ['javascript', 'google-chrome', 'websocket']
# ['python', 'pandas', 'aggregate', 'pandas-groupby']
# ['python', 'pandas', 'aggregate', 'pandas-groupby']
# ['in-app-purchase', 'ios']
# ['in-app-purchase', 'ios']
# ['asp.net-core', 'asp.net-core']
# ['asp.net-core']
# ['julia']
# ['julia']
# ['r']
# ['r']
# ['ios', 'ios-simulator', 'ios-darkmode']
# ['ios', 'ios-simulator', 'ios-darkmode']
# ['java', 'inheritance', 'overriding', 'shadowing', 'package-private']
# ['java', 'inheritance', 'overriding', 'shadowing', 'package-private']
# ['c++', 'templates', 'inheritance', 'unique-ptr']
# ['c++', 'templates', 'inheritance', 'unique-ptr']
# ['android', 'android-studio', 'avd']
# ['android', 'android-studio', 'avd']
# ['c', 'function', 'function-pointers']
# ['c', 'function', 'function-pointers']
# ['java', 'string']
# ['java', 'string']
# ['java', 'performance', 'x', 'jit']
# ['java', 'performance', 'x', 'jit']
# ['php', 'image', 'image-processing', 'png', 'php-gd']
# ['php', 'image', 'image-processing', 'png', 'php-gd']
# ['c++', 'c++-standard-library', 'c++', 'accumulate']
# ['c++', 'c++-standard-library', 'accumulate']
# ['ios', 'xcode', 'react-native', 'core-data', 'xcode']
# ['ios', 'xcode', 'react-native', 'core-data']
# ['android', 'ubuntu', 'emulation']
# ['android', 'ubuntu', 'emulation']
# ['java', 'spring', 'proxy', 'singleton', 'dynamic-proxy']
# ['java', 'spring', 'proxy', 'singleton', 'dynamic-proxy']
# ['javascript', 'reactjs', 'react-native']
# ['javascript', 'reactjs', 'react-native']
# ['ios', 'xcode', 'xcode']
# ['ios', 'xcode']
# ['ios', 'react-native', 'info.plist']
# ['ios', 'react-native', 'info.plist']
# ['ios', 'xctest', 'xcuitest']
# ['ios', 'xctest', 'xcuitest']
# ['ios', 'swift', 'avaudioplayer', 'ios']
# ['ios', 'swift', 'avaudioplayer']
# ['kubernetes', 'yaml']
# ['kubernetes', 'yaml']
# ['c++', 'c++', 'templates', 'language-lawyer', 'template-deduction']
# ['c++', 'templates', 'language-lawyer', 'template-deduction']
# ['java', 'java', 'switch-statement']
# ['java', 'switch-statement']
# ['laravel', 'laravel', 'laravel-helper']
# ['laravel', 'laravel-helper']
# ['c#', '.net', 'asynchronous', 'async-await']
# ['c#', '.net', 'asynchronous', 'async-await']
# ['python', 'python', 'pandas', 'dataframe']
# ['python', 'pandas', 'dataframe']
# ['javascript', 'reactjs', 'sweetalert']
# ['javascript', 'reactjs', 'sweetalert']
# ['ios', 'reactjs', 'xcode', 'react-native']
# ['ios', 'reactjs', 'xcode', 'react-native']
# ['javascript', 'html', 'css', 'angular', 'ionic-framework']
# ['javascript', 'html', 'css', 'angular', 'ionic-framework']
# ['java', 'generics']
# ['java', 'generics']
# ['java', 'maven', 'intellij-idea']
# ['java', 'maven', 'intellij-idea']
# ['mongodb', 'macos', 'homebrew']
# ['mongodb', 'macos', 'homebrew']
# ['r']
# ['r']
# ['c#']
# ['c#']
# ['ios', 'xcode', 'xcode']
# ['ios', 'xcode']
# ['ios', 'ios-simulator', 'xcode', 'iphone-se']
# ['ios', 'ios-simulator', 'xcode', 'iphone-se']
# ['java', 'garbage-collection']
# ['java', 'garbage-collection']
# ['swift', 'avfoundation', 'ios']
# ['swift', 'avfoundation', 'ios']
# ['haskell']
# ['haskell']
# ['java', 'floating-point', 'double']
# ['java', 'floating-point', 'double']
# ['angular', 'webpack', 'angular', 'webpack-style-loader', 'angular-upgrade']
# ['angular', 'webpack', 'webpack-style-loader', 'angular-upgrade']
# ['c++', 'language-lawyer', 'overload-resolution', 'value-categories']
# ['c++', 'language-lawyer', 'overload-resolution', 'value-categories']
# ['c++', 'initialization', 'language-lawyer', 'c++', 'copy-elision']
# ['c++', 'initialization', 'language-lawyer', 'copy-elision']
# ['java', 'arraylist', 'collections', 'concurrentmodification']
# ['java', 'arraylist', 'collections', 'concurrentmodification']
# ['file-io', 'julia']
# ['file-io', 'julia']
# ['emacs', 'gnupg']
# ['emacs', 'gnupg']
# ['c++', 'visual-c++', 'c++', 'language-lawyer', 'undefined-behavior']
# ['c++', 'visual-c++', 'language-lawyer', 'undefined-behavior']
# ['office', 'microsoft-graph', 'outlook-restapi']
# ['office', 'microsoft-graph', 'outlook-restapi']
# ['javascript', 'type-conversion']
# ['javascript', 'type-conversion']
# ['c', 'optimization', 'glibc', 'portability', 'strlen']
# ['c', 'optimization', 'glibc', 'portability', 'strlen']
# ['arrays', 'performance', 'rust', 'llvm-codegen']
# ['arrays', 'performance', 'rust', 'llvm-codegen']
# ['android', 'android-studio', 'android-manifest']
# ['android', 'android-studio', 'android-manifest']
# ['c++', 'language-lawyer', 'c++', 'std-source-location']
# ['c++', 'language-lawyer', 'std-source-location']
# ['c++', 'language-lawyer', 'undefined-behavior']
# ['c++', 'language-lawyer', 'undefined-behavior']
# ['c++', 'compiler-optimization', 'undefined-behavior', 'division', 'divide-by-zero']
# ['c++', 'compiler-optimization', 'undefined-behavior', 'division', 'divide-by-zero']
# ['c++', 'macros']
# ['c++', 'macros']
# ['android', 'android-room', 'android-lifecycle']
# ['android', 'android-room', 'android-lifecycle']
# ['c++', 'tuples', 'language-lawyer', 'padding']
# ['c++', 'tuples', 'language-lawyer', 'padding']
# ['pointers', 'rust']
# ['pointers', 'rust']
# ['android', 'android-studio', 'gradle', 'android-ndk', 'synchronization']
# ['android', 'android-studio', 'gradle', 'android-ndk', 'synchronization']
# ['c++', 'gcc', 'assembly', 'floating-point', 'micro-optimization']
# ['c++', 'gcc', 'assembly', 'floating-point', 'micro-optimization']
# ['android', 'android-studio', 'android-studio']
# ['android', 'android-studio']
# ['c++']
# ['c++']
# ['python', 'python']
# ['python']
# ['c', 'for-loop', 'pointers', 'declaration']
# ['c', 'for-loop', 'pointers', 'declaration']
# ['c++', 'const', 'immutability', 'const-cast']
# ['c++', 'const', 'immutability', 'const-cast']
# ['c++', 'c', 'linker', 'glibc', 'static-linking']
# ['c++', 'c', 'linker', 'glibc', 'static-linking']
# ['java', 'string', 'string-concatenation', 'string-pool', 'string-building']
# ['java', 'string', 'string-concatenation', 'string-pool', 'string-building']
# ['c++', 'performance', 'inheritance', 'c++', 'std-variant']
# ['c++', 'performance', 'inheritance', 'std-variant']
# ['swift', 'xcode', 'swiftui', 'ios']
# ['swift', 'xcode', 'swiftui', 'ios']
# ['c++', 'c++', 'object-slicing']
# ['c++', 'object-slicing']
# ['c++', 'variadic-templates', 'c++', 'default-arguments', 'std-source-location']
# ['c++', 'variadic-templates', 'default-arguments', 'std-source-location']
# ['c++', 'ternary-operator', 'operator-precedence']
# ['c++', 'ternary-operator', 'operator-precedence']
# ['c++', 'stl', 'language-lawyer', 'rvalue-reference', 'pass-by-rvalue-reference']
# ['c++', 'stl', 'language-lawyer', 'rvalue-reference', 'pass-by-rvalue-reference']
# ['ios', 'flutter', 'uiwebview']
# ['ios', 'flutter', 'uiwebview']
# ['c++', 'c++', 'c++']
# ['c++']
# ['haskell', 'parallel-processing', 'immutability', 'lazy-evaluation']
# ['haskell', 'parallel-processing', 'immutability', 'lazy-evaluation']
# ['php']
# ['php']
# ['ios', 'network-framework']
# ['ios', 'network-framework']
# ['c++', 'c++', 'optional', 'unions']
# ['c++', 'optional', 'unions']
# ['c++', 'arrays', 'casting', 'boolean']
# ['c++', 'arrays', 'casting', 'boolean']
# ['c++', 'optimization', 'constexpr', 'c++']
# ['c++', 'optimization', 'constexpr']
# ['ios', 'swift', 'xcode']
# ['ios', 'swift', 'xcode']
# ['javascript', 'async-await', 'es-promise']
# ['javascript', 'async-await', 'es-promise']
# ['c++', 'c++', 'auto', 'type-deduction', 'decltype-auto']
# ['c++', 'auto', 'type-deduction', 'decltype-auto']
# ['android', 'android-studio', 'android-layout', 'android-studio']
# ['android', 'android-studio', 'android-layout']
# ['c++', 'struct', 'reference', 'initialization', 'language-lawyer']
# ['c++', 'struct', 'reference', 'initialization', 'language-lawyer']
# ['c']
# ['c']
# ['python', 'debugging', 'logging']
# ['python', 'debugging', 'logging']
# ['python', 'pandas', 'numpy', 'group-by']
# ['python', 'pandas', 'numpy', 'group-by']
# ['c++', 'visual-c++', 'new-operator', 'compiler-bug', 'aggregate-initialization']
# ['c++', 'visual-c++', 'new-operator', 'compiler-bug', 'aggregate-initialization']
# ['c#', 'asp.net', 'docker']
# ['c#', 'asp.net', 'docker']
# ['python', 'scope']
# ['python', 'scope']
# ['swift', 'xcode', 'ios']
# ['swift', 'xcode', 'ios']
# ['c']
# ['c']
# ['c++', 'c++', 'auto', 'copy-elision', 'decltype-auto']
# ['c++', 'auto', 'copy-elision', 'decltype-auto']
# ['python', 'tuples']
# ['python', 'tuples']
# ['xcode', 'xcode']
# ['xcode']
# ['c++', 'stl', 'language-lawyer', 'c++-standard-library']
# ['c++', 'stl', 'language-lawyer', 'c++-standard-library']
# ['python', 'pandas']
# ['python', 'pandas']
# ['c++', 'initialization', 'stdarray']
# ['c++', 'initialization', 'stdarray']
# ['android', 'compiler-errors', 'android-emulator']
# ['android', 'compiler-errors', 'android-emulator']
# ['ruby']
# ['ruby']
# ['c++', 'optimization', 'x', 'intel', 'micro-optimization']
# ['c++', 'optimization', 'x', 'intel', 'micro-optimization']
# ['github', 'continuous-integration', 'github-actions']
# ['github', 'continuous-integration', 'github-actions']
# ['python', 'numpy', 'data-science']
# ['python', 'numpy', 'data-science']
# ['java', 'object', 'primitive', 'equals-operator']
# ['java', 'object', 'primitive', 'equals-operator']
# ['c++', 'asynchronous', 'coroutine', 'c++', 'c++-coroutine']
# ['c++', 'asynchronous', 'coroutine', 'c++-coroutine']
# ['c', 'arrays', 'pointers', 'unary-operator', 'postfix-operator']
# ['c', 'arrays', 'pointers', 'unary-operator', 'postfix-operator']
# ['swift', 'wkwebview', 'avaudiosession', 'ios', 'ios-background-mode']
# ['swift', 'wkwebview', 'avaudiosession', 'ios', 'ios-background-mode']
# ['javascript', 'html', 'dom-events']
# ['javascript', 'html', 'dom-events']
# ['java', 'hibernate', 'jpa', 'optimistic-locking', 'optimistic-concurrency']
# ['java', 'hibernate', 'jpa', 'optimistic-locking', 'optimistic-concurrency']
# ['mysql', 'sql', 'database', 'intellij-idea', 'mysql-workbench']
# ['mysql', 'sql', 'database', 'intellij-idea', 'mysql-workbench']
# ['c#', 'asp.net-mvc', 'asp.net-core', '.net-core']
# ['c#', 'asp.net-mvc', 'asp.net-core', '.net-core']
# ['ios', 'app-store', 'appstoreconnect']
# ['ios', 'app-store', 'appstoreconnect']
# ['python', 'anaconda', 'conda']
# ['python', 'anaconda', 'conda']
# ['android', 'android-studio', 'proguard', 'androidx']
# ['android', 'android-studio', 'proguard', 'androidx']
# ['flutter']
# ['flutter']
# ['vue.js']
# ['vue.js']
# ['php', 'mysql', 'concurrency', 'race-condition']
# ['php', 'mysql', 'concurrency', 'race-condition']
# ['.net', 'asp.net-core', '.net-core', 'csproj', 'asp.net-core']
# ['.net', 'asp.net-core', '.net-core', 'csproj']
# ['laravel']
# ['laravel']
# ['ios', 'swift', 'ios', 'networkextension', 'ipados']
# ['ios', 'swift', 'networkextension', 'ipados']
# ['python', 'python', 'list', 'dictionary']
# ['python', 'list', 'dictionary']
# ['java', 'c', 'floating-point', 'printf']
# ['java', 'c', 'floating-point', 'printf']
# ['c++']
# ['c++']
# ['java', 'arraylist']
# ['java', 'arraylist']
# ['python', 'r', 'excel', 'vba', 'pdf']
# ['python', 'r', 'excel', 'vba', 'pdf']
# ['c++', 'language-lawyer']
# ['c++', 'language-lawyer']
# ['java', 'android', 'file']
# ['java', 'android', 'file']
# ['c++', 'language-lawyer', 'c++', 'variadic-templates', 'template-deduction']
# ['c++', 'language-lawyer', 'variadic-templates', 'template-deduction']
# ['c++', 'templates', 'recursion', 'template-specialization', 'factorial']
# ['c++', 'templates', 'recursion', 'template-specialization', 'factorial']
# ['python', 'pandas', 'transform', 'pandas-groupby']
# ['python', 'pandas', 'transform', 'pandas-groupby']
# ['react-native', 'redux-persist']
# ['react-native', 'redux-persist']
# ['c++', 'c++', 'compile-time', 'static-assert']
# ['c++', 'compile-time', 'static-assert']
# ['javascript', 'html', 'css', 'css-multicolumn-layout']
# ['javascript', 'html', 'css', 'css-multicolumn-layout']
# ['c++', 'language-lawyer', 'c++', 'stdlaunder']
# ['c++', 'language-lawyer', 'stdlaunder']
# ['c++', 'performance', 'c++', 'stl', 'insert']
# ['c++', 'performance', 'stl', 'insert']
# ['c++', 'c++', 'implicit-conversion', 'nullptr']
# ['c++', 'implicit-conversion', 'nullptr']
# ['javascript', 'html', 'css']
# ['javascript', 'html', 'css']
# ['java', 'accessibility']
# ['java', 'accessibility']
# ['python', 'python', 'slice']
# ['python', 'slice']
# ['android', 'android-studio', 'gradle-kotlin-dsl']
# ['android', 'android-studio', 'gradle-kotlin-dsl']
# ['c++', 'c', 'performance']
# ['c++', 'c', 'performance']
# ['c++']
# ['c++']
# ['swiftui']
# ['swiftui']
# ['c++', 'templates', 'template-specialization']
# ['c++', 'templates', 'template-specialization']
# ['haskell', 'lazy-evaluation', 'ghci']
# ['haskell', 'lazy-evaluation', 'ghci']
# ['rust', 'compiler-optimization', 'llvm-codegen']
# ['rust', 'compiler-optimization', 'llvm-codegen']
# ['rust', 'x', 'bigint', 'int', 'llvm-codegen']
# ['rust', 'x', 'bigint', 'int', 'llvm-codegen']
# ['c++', 'floating-point', 'clang']
# ['c++', 'floating-point', 'clang']
# ['c#']
# ['c#']
# ['git']
# ['git']
# ['xcode', 'storyboard']
# ['xcode', 'storyboard']
# ['python', 'matplotlib', 'seaborn']
# ['python', 'matplotlib', 'seaborn']
# ['xcode', 'xcode']
# ['xcode']
# ['list', 'haskell', 'is-empty', 'empty-list']
# ['list', 'haskell', 'is-empty', 'empty-list']
# ['c++', 'asynchronous', 'c++', 'c++-coroutine']
# ['c++', 'asynchronous', 'c++-coroutine']
# ['c++', 'c++']
# ['c++']
# ['java', 'security', 'random']
# ['java', 'security', 'random']
# ['python', 'algorithm', 'markov-chains', 'procedural-generation']
# ['python', 'algorithm', 'markov-chains', 'procedural-generation']
# ['c++', 'algorithm', 'if-statement', 'while-loop', 'simplify']
# ['c++', 'algorithm', 'if-statement', 'while-loop', 'simplify']
# ['c++']
# ['c++']
# ['python', 'arrays', 'list', 'numpy', 'indexing']
# ['python', 'arrays', 'list', 'numpy', 'indexing']
# ['c++', 'casting', 'type-conversion', 'ros', 'typecasting-operator']
# ['c++', 'casting', 'type-conversion', 'ros', 'typecasting-operator']
# ['c#', 'asp.net-core', '.net-core', 'entity-framework-core', '.net-core']
# ['c#', 'asp.net-core', '.net-core', 'entity-framework-core']
# ['sql-server', 'linux', 'tcpclient']
# ['sql-server', 'linux', 'tcpclient']
# ['c++', 'overloading', 'ambiguous-call']
# ['c++', 'overloading', 'ambiguous-call']
# ['uikit', 'uiwindow', 'uiapplication', 'uiscene']
# ['uikit', 'uiwindow', 'uiapplication', 'uiscene']
# ['c++', 'c++', 'gcc']
# ['c++', 'gcc']
# ['laravel', 'docker', 'docker-compose', 'dockerfile']
# ['laravel', 'docker', 'docker-compose', 'dockerfile']
# ['c++', 'initializer-list']
# ['c++', 'initializer-list']
# ['javascript']
# ['javascript']
# ['python', 'python', 'list', 'concatenation']
# ['python', 'list', 'concatenation']
# ['haskell', 'syntax', 'escaping', 'lexer']
# ['haskell', 'syntax', 'escaping', 'lexer']
# ['c++', 'c++', 'c++']
# ['c++']
# ['java', 'string']
# ['java', 'string']
# ['android', 'react-native']
# ['android', 'react-native']
# ['xcode', 'cocoapods', 'xcode']
# ['xcode', 'cocoapods']
# ['c++', 'shared-ptr', 'void']
# ['c++', 'shared-ptr', 'void']
# ['c++', 'shared-ptr', 'weak-ptr', 'private-inheritance', 'enable-shared-from-this']
# ['c++', 'shared-ptr', 'weak-ptr', 'private-inheritance', 'enable-shared-from-this']
# ['c++', 'multithreading']
# ['c++', 'multithreading']
# ['java', 'jvm', 'javac', 'bytecode']
# ['java', 'jvm', 'javac', 'bytecode']
# ['typescript']
# ['typescript']
# ['c++', 'performance', 'cout', 'string-literals']
# ['c++', 'performance', 'cout', 'string-literals']
# ['c++', 'c++', 'c++']
# ['c++']
# ['c++', 'performance', 'stdstring', 'compound-assignment']
# ['c++', 'performance', 'stdstring', 'compound-assignment']
# ['python', 'python', 'numpy', 'tensorflow', 'artificial-intelligence']
# ['python', 'numpy', 'tensorflow', 'artificial-intelligence']
# ['c++', 'int', 'size', 'system', 'bit']
# ['c++', 'int', 'size', 'system', 'bit']
# ['uiswitch', 'xcode']
# ['uiswitch', 'xcode']
# ['python', 'python', 'tensorflow', 'tensorflow-lite']
# ['python', 'tensorflow', 'tensorflow-lite']
# ['java', 'android', 'android-package-managers', 'android-multiple-users', 'android-work-profile']
# ['java', 'android', 'android-package-managers', 'android-multiple-users', 'android-work-profile']
# ['c++', 'smart-pointers', 'stdvector', 'move-semantics']
# ['c++', 'smart-pointers', 'stdvector', 'move-semantics']
# ['css', 'macos', 'google-chrome', 'autofill']
# ['css', 'macos', 'google-chrome', 'autofill']
# ['swift', 'listview', 'swiftui', 'autoscroll']
# ['swift', 'listview', 'swiftui', 'autoscroll']
# ['ios', 'objective-c', 'swift', 'ios']
# ['ios', 'objective-c', 'swift']
# ['swift', 'swiftui']
# ['swift', 'swiftui']
# ['c++', 'c', 'function-pointers', 'function-declaration']
# ['c++', 'c', 'function-pointers', 'function-declaration']
# ['c++', 'c++', 'backwards-compatibility', 'c++']
# ['c++', 'backwards-compatibility']
# ['c++']
# ['c++']
# ['objective-c', 'swift', 'xcode', 'macos']
# ['objective-c', 'swift', 'xcode', 'macos']
# ['c++', 'templates', 'c++', 'c++-concepts']
# ['c++', 'templates', 'c++-concepts']
# ['c++', 'language-lawyer', 'c++']
# ['c++', 'language-lawyer']
# ['c#', '.net', 'random']
# ['c#', '.net', 'random']
# ['java', 'android', 'android-workmanager']
# ['java', 'android', 'android-workmanager']
# ['bash', 'shell', 'sh', 'alias']
# ['bash', 'shell', 'sh', 'alias']
# ['haskell', 'types', 'typeclass', 'type-mismatch', 'typechecking']
# ['haskell', 'types', 'typeclass', 'type-mismatch', 'typechecking']
# ['c++', 'c', 'bit-manipulation']
# ['c++', 'c', 'bit-manipulation']
# ['java', 'docker', 'linux-kernel', 'amazon-ecs', 'mmap']
# ['java', 'docker', 'linux-kernel', 'amazon-ecs', 'mmap']
# ['algorithm', 'data-structures', 'big-o']
# ['algorithm', 'data-structures', 'big-o']
# ['c++', 'stddeque']
# ['c++', 'stddeque']
# ['javascript', 'reactjs', 'checkbox']
# ['javascript', 'reactjs', 'checkbox']
# ['python', 'python', 'tensorflow', 'neural-network', 'tensorflow']
# ['python', 'tensorflow', 'neural-network']
# ['c#', 'asp.net-apicontroller', 'application-error']
# ['c#', 'asp.net-apicontroller', 'application-error']
# ['math', 'geometry', 'pseudocode']
# ['math', 'geometry', 'pseudocode']
# ['performance', 'rust']
# ['performance', 'rust']
# ['node.js', 'kerberos', 'ntlm', 'ntlm-authentication', 'ntlmv']
# ['node.js', 'kerberos', 'ntlm', 'ntlm-authentication', 'ntlmv']
# ['c', 'time.h']
# ['c', 'time.h']
# ['sql', 'multithreading', 'powershell', 'asynchronous', 'parallel-processing']
# ['sql', 'multithreading', 'powershell', 'asynchronous', 'parallel-processing']
# ['haskell', 'type-safety', 'type-alias', 'newtype']
# ['haskell', 'type-safety', 'type-alias', 'newtype']
# ['python', 'tensorflow', 'keras', 'semantic-segmentation', 'tensorrt']
# ['python', 'tensorflow', 'keras', 'semantic-segmentation', 'tensorrt']
# ['swiftui', 'xcode']
# ['swiftui', 'xcode']
# ['django', 'swagger', 'swagger-ui']
# ['django', 'swagger', 'swagger-ui']
# ['postgresql', 'pgadmin']
# ['postgresql', 'pgadmin']
# ['git', 'git-checkout']
# ['git', 'git-checkout']
# ['python', 'arrays', 'file', 'out-of-memory']
# ['python', 'arrays', 'file', 'out-of-memory']
# ['c#', 'list', 'sorting']
# ['c#', 'list', 'sorting']
# ['c++', 'exception', 'memory-management', 'unique-ptr']
# ['c++', 'exception', 'memory-management', 'unique-ptr']
# ['html', 'css', 'flexbox', 'overflow']
# ['html', 'css', 'flexbox', 'overflow']
# ['javascript', 'angular', 'rxjs', 'css-transitions', 'ngrx']
# ['javascript', 'angular', 'rxjs', 'css-transitions', 'ngrx']
# ['c#', 'sql-server', 'entity-framework', 'entity-framework', 'database-concurrency']
# ['c#', 'sql-server', 'entity-framework', 'database-concurrency']
# ['ios', 'swift', 'uiwindow', 'ios', 'uiscenedelegate']
# ['ios', 'swift', 'uiwindow', 'uiscenedelegate']
# ['swift', 'swiftui']
# ['swift', 'swiftui']
# ['python', 'python', 'list']
# ['python', 'list']
# ['azure-devops', 'azure-pipelines']
# ['azure-devops', 'azure-pipelines']
# ['php', 'error-handling', 'try-catch']
# ['php', 'error-handling', 'try-catch']
# ['xcode', 'beta']
# ['xcode', 'beta']
# ['javascript', 'reactjs', 'npm', 'github-pages']
# ['javascript', 'reactjs', 'npm', 'github-pages']
# ['javascript', 'arrays', 'string']
# ['javascript', 'arrays', 'string']
# ['operator-overloading', 'perl']
# ['operator-overloading', 'perl']
# ['c++', 'c++', 'friend']
# ['c++', 'friend']
# ['java', 'docker', 'javafx', 'java', 'openjfx']
# ['java', 'docker', 'javafx', 'openjfx']
# ['c#', '.net', 'windows', 'winforms', 'visual-c++']
# ['c#', '.net', 'windows', 'winforms', 'visual-c++']
# ['python', 'mathematical-optimization', 'itertools', 'linear-programming']
# ['python', 'mathematical-optimization', 'itertools', 'linear-programming']
# ['java', 'jvm', 'liferay']
# ['java', 'jvm', 'liferay']
# ['angular', 'localization', 'lazy-loading', 'angular']
# ['angular', 'localization', 'lazy-loading']
# ['java', 'overloading', 'method-reference', 'functional-interface', 'arity']
# ['java', 'overloading', 'method-reference', 'functional-interface', 'arity']
# ['python', 'logarithm']
# ['python', 'logarithm']
# ['git', 'version-control', 'command-line-interface', 'git-bash']
# ['git', 'version-control', 'command-line-interface', 'git-bash']
# ['ios', 'ios-darkmode']
# ['ios', 'ios-darkmode']
# ['c++', 'c', 'benchmarking']
# ['c++', 'c', 'benchmarking']
# ['c++', 'if-statement', 'c++']
# ['c++', 'if-statement']
# ['angular', 'typescript']
# ['angular', 'typescript']
# ['ios', 'ios', 'ios-darkmode']
# ['ios', 'ios-darkmode']
# ['xcode', 'testflight', 'fastlane', 'appstoreconnect']
# ['xcode', 'testflight', 'fastlane', 'appstoreconnect']
# ['c++', 'c++', 'filesize', 'c++-standard-library']
# ['c++', 'filesize', 'c++-standard-library']
# ['c++', 'c++']
# ['c++']
# ['c++', 'templates', 'embedded', 'fault-tolerance']
# ['c++', 'templates', 'embedded', 'fault-tolerance']
# ['c++', 'algorithm', 'reference', 'stl', 'c++']
# ['c++', 'algorithm', 'reference', 'stl']
# ['xcode', 'xcode', 'xcode']
# ['xcode']
# ['android', 'google-api-java-client', 'google-developers-console']
# ['android', 'google-api-java-client', 'google-developers-console']
# ['c++', 'optimization', 'memory-alignment', 'memory-layout', 'struct-member-alignment']
# ['c++', 'optimization', 'memory-alignment', 'memory-layout', 'struct-member-alignment']
# ['c#', '.net', 'visual-studio', '.net-standard', 'c#']
# ['c#', '.net', 'visual-studio', '.net-standard']
# ['c++', 'compiler-optimization']
# ['c++', 'compiler-optimization']
# ['java', 'sorting', 'parallel-processing']
# ['java', 'sorting', 'parallel-processing']
# ['angular']
# ['angular']
# ['python', 'python', 'slice']
# ['python', 'slice']
# ['ios', 'swift', 'statusbar', 'ios']
# ['ios', 'swift', 'statusbar']
# ['c++', 'algorithm', 'c++', 'counting', 'c++-standard-library']
# ['c++', 'algorithm', 'counting', 'c++-standard-library']
# ['python', 'anaconda', 'conda']
# ['python', 'anaconda', 'conda']
# ['ios', 'swift', 'uiviewcontroller', 'uikit', 'ios']
# ['ios', 'swift', 'uiviewcontroller', 'uikit']
# ['git-bash', 'windows-terminal']
# ['git-bash', 'windows-terminal']
# ['python', 'opencv', 'image-processing', 'computer-vision', 'image-thresholding']
# ['python', 'opencv', 'image-processing', 'computer-vision', 'image-thresholding']
# ['ios', 'uigesturerecognizer', 'ios']
# ['ios', 'uigesturerecognizer']
# ['c++', 'algorithm', 'c++', 'c++-standard-library', 'iterator-range']
# ['c++', 'algorithm', 'c++-standard-library', 'iterator-range']
# ['ios', 'swift', 'swiftui']
# ['ios', 'swift', 'swiftui']
# ['c++', 'variadic-templates']
# ['c++', 'variadic-templates']
# ['ios', 'storyboard', 'uistoryboard', 'ios']
# ['ios', 'storyboard', 'uistoryboard']
# ['c#', 'asp.net-core', 'razor-pages', 'asp.net-core', 'system.text.json']
# ['c#', 'asp.net-core', 'razor-pages', 'system.text.json']
# ['swift', 'swiftui']
# ['swift', 'swiftui']
# ['android', 'android-studio', 'gradle', 'kotlin', 'flutter']
# ['android', 'android-studio', 'gradle', 'kotlin', 'flutter']
# ['c++', 'gcc', 'function-pointers']
# ['c++', 'gcc', 'function-pointers']
# ['cocoapods']
# ['cocoapods']
# ['c++', 'c++', 'inheritance']
# ['c++', 'inheritance']
# ['android', 'react-native', 'react-native-android', 'expo']
# ['android', 'react-native', 'react-native-android', 'expo']
# ['python', 'matplotlib', 'pycharm']
# ['python', 'matplotlib', 'pycharm']
# ['c++', 'c++', 'lambda', 'unique-ptr', 'capture-list']
# ['c++', 'lambda', 'unique-ptr', 'capture-list']
# ['swift', 'swiftui']
# ['swift', 'swiftui']
# ['c++', 'x', 'compiler-optimization', 'calling-convention', 'abi']
# ['c++', 'x', 'compiler-optimization', 'calling-convention', 'abi']
# ['ios', 'swift', 'swiftui']
# ['ios', 'swift', 'swiftui']
# ['javascript', 'vue.js', 'webpack', 'webpack-dev-server']
# ['javascript', 'vue.js', 'webpack', 'webpack-dev-server']
# ['node.js', 'reactjs', 'laravel', 'npm', 'webpack']
# ['node.js', 'reactjs', 'laravel', 'npm', 'webpack']
# ['c#', 'struct', 'value-type', 'readonly-attribute']
# ['c#', 'struct', 'value-type', 'readonly-attribute']
# ['swift', 'textfield', 'swiftui', 'first-responder']
# ['swift', 'textfield', 'swiftui', 'first-responder']
# ['android', 'android']
# ['android']
# ['ios', 'swift', 'swiftui']
# ['ios', 'swift', 'swiftui']
# ['java', 'lambda', 'java-stream']
# ['java', 'lambda', 'java-stream']
# ['c++', 'string', 'c++', 'stdstring', 'c++']
# ['c++', 'string', 'stdstring']
# ['swift']
# ['swift']
# ['javascript', 'language-lawyer', 'specifications', 'atan']
# ['javascript', 'language-lawyer', 'specifications', 'atan']
# ['swift', 'modal-dialog', 'swiftui']
# ['swift', 'modal-dialog', 'swiftui']
# ['objective-c', 'uisearchbar', 'xcode', 'ios']
# ['objective-c', 'uisearchbar', 'xcode', 'ios']
# ['macos', 'vim', 'terminal', 'locale', 'local']
# ['macos', 'vim', 'terminal', 'locale', 'local']
# ['c++', 'c++', 'enums', 'const', 'language-lawyer']
# ['c++', 'enums', 'const', 'language-lawyer']
# ['android', 'sharedpreferences', 'android']
# ['android', 'sharedpreferences']
# ['python', 'pycharm']
# ['python', 'pycharm']
# ['c++', 'function', 'pointers', 'overloading']
# ['c++', 'function', 'pointers', 'overloading']
# ['python', 'duplicates']
# ['python', 'duplicates']
# ['java', 'if-statement', 'design-patterns']
# ['java', 'if-statement', 'design-patterns']
# ['android', 'firebase', 'cordova', 'ionic-framework', 'ionic']
# ['android', 'firebase', 'cordova', 'ionic-framework', 'ionic']
# ['c++', 'stl', 'stl-algorithm', 'stdtuple', 'uniform-initialization']
# ['c++', 'stl', 'stl-algorithm', 'stdtuple', 'uniform-initialization']
# ['swift', 'swiftui']
# ['swift', 'swiftui']
# ['swift', 'swiftui', 'ios', 'sf-symbols']
# ['swift', 'swiftui', 'ios', 'sf-symbols']
# ['javascript', 'arrays', 'functional-programming', 'prefix-sum']
# ['javascript', 'arrays', 'functional-programming', 'prefix-sum']
# ['javascript', 'typescript']
# ['javascript', 'typescript']
# ['uiscrollview', 'ios-autolayout', 'xcode']
# ['uiscrollview', 'ios-autolayout', 'xcode']
# ['c#', 'entity-framework', 'asp.net-core', '.net-core', 'csproj']
# ['c#', 'entity-framework', 'asp.net-core', '.net-core', 'csproj']
# ['ios', 'swift', 'xcode', 'swiftui']
# ['ios', 'swift', 'xcode', 'swiftui']
# ['angular', 'ionic-framework']
# ['angular', 'ionic-framework']
# ['swiftui']
# ['swiftui']
# ['c++', 'function', 'language-lawyer', 'stdstring']
# ['c++', 'function', 'language-lawyer', 'stdstring']
# ['c++', 'stdstring', 'c++']
# ['c++', 'stdstring']
# ['python', 'random', 'colors']
# ['python', 'random', 'colors']
# ['ios', 'swift', 'macos', 'video', 'video-encoding']
# ['ios', 'swift', 'macos', 'video', 'video-encoding']
# ['c++', 'reference', 'language-lawyer', 'memory-layout', 'storage-duration']
# ['c++', 'reference', 'language-lawyer', 'memory-layout', 'storage-duration']
# ['ios', 'xcode', 'xcode']
# ['ios', 'xcode']
# ['swift', 'xcode', 'import']
# ['swift', 'xcode', 'import']
# ['typescript']
# ['typescript']
# ['ios', 'keychain', 'ios', 'security-framework']
# ['ios', 'keychain', 'security-framework']
# ['node.js', 'firebase', 'google-cloud-functions', 'firebase-cli']
# ['node.js', 'firebase', 'google-cloud-functions', 'firebase-cli']
# ['android', 'androidx', 'android', 'calligraphy']
# ['android', 'androidx', 'calligraphy']
# ['.net', '.net-core', 'azure-devops', 'azure-pipelines']
# ['.net', '.net-core', 'azure-devops', 'azure-pipelines']
# ['swift', 'swiftui']
# ['swift', 'swiftui']
# ['javascript', 'firebase', 'google-cloud-functions', 'firebase-admin', 'google-auth-library']
# ['javascript', 'firebase', 'google-cloud-functions', 'firebase-admin', 'google-auth-library']
# ['r', 'shiny', 'hover', 'click', 'smartphone']
# ['r', 'shiny', 'hover', 'click', 'smartphone']
# ['android', 'facebook', 'firebase', 'firebase-authentication', 'facebook-authentication']
# ['android', 'facebook', 'firebase', 'firebase-authentication', 'facebook-authentication']
# ['c++', 'c++', 'address-operator']
# ['c++', 'address-operator']
# ['ios', 'swiftui']
# ['ios', 'swiftui']
# ['c++', 'header', 'include', 'c++']
# ['c++', 'header', 'include']
# ['reactjs', 'npm', 'create-react-app']
# ['reactjs', 'npm', 'create-react-app']
# ['java', 'operators']
# ['java', 'operators']
# ['angular', 'git', 'typescript', 'angular']
# ['angular', 'git', 'typescript']
# ['bash', 'shell', 'environment-variables', 'zsh', 'macos-catalina']
# ['bash', 'shell', 'environment-variables', 'zsh', 'macos-catalina']
# ['c++', 'c++', 'inline']
# ['c++', 'inline']
# ['android', 'android-studio', 'gradle', 'libraries']
# ['android', 'android-studio', 'gradle', 'libraries']
# ['android', 'google-cloud-platform']
# ['android', 'google-cloud-platform']
# ['swift', 'list', 'swiftui']
# ['swift', 'list', 'swiftui']
# ['ios', 'xcode']
# ['ios', 'xcode']
# ['ios', 'viewcontroller', 'modalviewcontroller', 'ios']
# ['ios', 'viewcontroller', 'modalviewcontroller']
# ['python', 'math', 'hash', 'floating-point', 'pi']
# ['python', 'math', 'hash', 'floating-point', 'pi']
# ['swift', 'swift']
# ['swift']
# ['c++', 'if-statement']
# ['c++', 'if-statement']
# ['c', 'arrays', 'size', 'language-lawyer', 'pointer-arithmetic']
# ['c', 'arrays', 'size', 'language-lawyer', 'pointer-arithmetic']
# ['angular', 'typescript', 'viewchild', 'angular']
# ['angular', 'typescript', 'viewchild']
# ['angular', 'angular']
# ['angular']
# ['c++', 'c++']
# ['c++']
# ['swift', 'ios', 'swiftui']
# ['swift', 'ios', 'swiftui']
# ['java', 'maven', 'spring-boot', 'pom.xml']
# ['java', 'maven', 'spring-boot', 'pom.xml']
# ['python', 'python', 'list', 'tuples', 'splat']
# ['python', 'list', 'tuples', 'splat']
# ['c++', 'gcc', 'compilation', 'clang', 'compiler-optimization']
# ['c++', 'gcc', 'compilation', 'clang', 'compiler-optimization']
# ['ios', 'uikit', 'uisegmentedcontrol', 'ios']
# ['ios', 'uikit', 'uisegmentedcontrol']
# ['javascript', 'angular', 'typescript', 'module', 'angular']
# ['javascript', 'angular', 'typescript', 'module']
# ['c++', 'c++', 'stdstring']
# ['c++', 'stdstring']
# ['swift', 'swiftui']
# ['swift', 'swiftui']
# ['java', 'multithreading', 'lambda', 'compilation', 'functional-interface']
# ['java', 'multithreading', 'lambda', 'compilation', 'functional-interface']
# ['c++', 'c', 'arrays', 'static', 'const']
# ['c++', 'c', 'arrays', 'static', 'const']
# ['c', 'bitbit']
# ['c', 'bitbit']
# ['c++', 'language-lawyer', 'constexpr', 'c++', 'class-template']
# ['c++', 'language-lawyer', 'constexpr', 'class-template']
# ['python', 'python', 'performance', 'for-loop', 'sum']
# ['python', 'performance', 'for-loop', 'sum']
# ['ios', 'uiviewcontroller', 'uikit', 'modalviewcontroller', 'ios']
# ['ios', 'uiviewcontroller', 'uikit', 'modalviewcontroller']
# ['android', 'apk', 'inputstream', 'android-package-managers', 'scoped-storage']
# ['android', 'apk', 'inputstream', 'android-package-managers', 'scoped-storage']
# ['c++', 'clang', 'c++', 'boost-variant']
# ['c++', 'clang', 'boost-variant']
# ['reactjs', 'material-ui']
# ['reactjs', 'material-ui']
# ['c++', 'optimization', 'algebra', 'micro-optimization', 'sqrt']
# ['c++', 'optimization', 'algebra', 'micro-optimization', 'sqrt']
# ['android', 'gradle', 'kapt']
# ['android', 'gradle', 'kapt']
# ['java', 'android', 'json', 'servlets']
# ['java', 'android', 'json', 'servlets']
# ['c++', 'c++', 'c++', 'string-comparison', 'string-literals']
# ['c++', 'string-comparison', 'string-literals']
# ['c++', 'language-lawyer', 'c++']
# ['c++', 'language-lawyer']
# ['angular', 'angular-cli', 'polyfills', 'angular']
# ['angular', 'angular-cli', 'polyfills']
# ['ios', 'xcode', 'xcode', 'xcode']
# ['ios', 'xcode']
# ['java', 'maven', 'spring-boot']
# ['java', 'maven', 'spring-boot']
# ['c#', 'asynchronous', 'async-await']
# ['c#', 'asynchronous', 'async-await']
# ['c++', 'boolean', 'undefined-behavior', 'evaluation', 'abi']
# ['c++', 'boolean', 'undefined-behavior', 'evaluation', 'abi']
# ['view', 'background', 'background-color', 'modifier', 'swiftui']
# ['view', 'background', 'background-color', 'modifier', 'swiftui']
# ['java', 'multithreading', 'concurrency', 'java-threads', 'thread-synchronization']
# ['java', 'multithreading', 'concurrency', 'java-threads', 'thread-synchronization']
# ['python', 'list']
# ['python', 'list']
# ['c++', 'rust', 'traits', 'c++-concepts']
# ['c++', 'rust', 'traits', 'c++-concepts']
# ['c++', 'gcc', 'assembly', 'x', 'bigint']
# ['c++', 'gcc', 'assembly', 'x', 'bigint']
# ['c', 'gcc', 'assembly', 'x', 'nasm']
# ['c', 'gcc', 'assembly', 'x', 'nasm']
# ['c++', 'initialization', 'c++', 'compile-time', 'stdarray']
# ['c++', 'initialization', 'compile-time', 'stdarray']
# ['google-chrome', 'google-chrome-devtools']
# ['google-chrome', 'google-chrome-devtools']
# ['c++', 'c', 'language-lawyer', 'signed', 'integer-overflow']
# ['c++', 'c', 'language-lawyer', 'signed', 'integer-overflow']
# ['javascript', 'reactjs', 'react-native', 'mocha']
# ['javascript', 'reactjs', 'react-native', 'mocha']
# ['c++']
# ['c++']
# ['java']
# ['java']
# ['ios', 'swiftui']
# ['ios', 'swiftui']
# ['android', 'android-ndk']
# ['android', 'android-ndk']
# ['c++', 'performance', 'x', 'processing-efficiency', 'floor']
# ['c++', 'performance', 'x', 'processing-efficiency', 'floor']
# ['javascript', 'math', 'random', 'statistics']
# ['javascript', 'math', 'random', 'statistics']
# ['angular', 'angular-material', 'hyperledger-composer']
# ['angular', 'angular-material', 'hyperledger-composer']
# ['swift', 'swiftui']
# ['swift', 'swiftui']
# ['haskell', 'fold', 'continuations', 'continuation-passing']
# ['haskell', 'fold', 'continuations', 'continuation-passing']
# ['typescript']
# ['typescript']
# ['java', 'compiler-errors', 'language-specifications']
# ['java', 'compiler-errors', 'language-specifications']
# ['ios', 'swift', 'swiftui', 'xcode']
# ['ios', 'swift', 'swiftui', 'xcode']
# ['c++', 'c++']
# ['c++']
# ['typescript', 'service-worker', 'web-worker']
# ['typescript', 'service-worker', 'web-worker']
# ['vue.js', 'webpack', 'sass', 'vue-cli', 'node-sass']
# ['vue.js', 'webpack', 'sass', 'vue-cli', 'node-sass']
# ['ld']
# ['ld']
# ['c++', 'string', 'initialization', 'string-literals', 'memset']
# ['c++', 'string', 'initialization', 'string-literals', 'memset']
# ['angular', 'typescript', 'angular', 'viewchild', 'angular']
# ['angular', 'typescript', 'viewchild']
# ['android', 'android-studio', 'android-gradle-plugin', 'gradle-plugin']
# ['android', 'android-studio', 'android-gradle-plugin', 'gradle-plugin']
# ['javascript', 'vue.js', 'webpack', 'source-maps']
# ['javascript', 'vue.js', 'webpack', 'source-maps']
# ['android', 'facebook', 'facebook-graph-api', 'flutter']
# ['android', 'facebook', 'facebook-graph-api', 'flutter']
# ['python']
# ['python']
# ['ios', 'swift', 'ios-darkmode']
# ['ios', 'swift', 'ios-darkmode']
# ['ios', 'uicollectionview', 'swiftui', 'ios']
# ['ios', 'uicollectionview', 'swiftui']
# ['c#']
# ['c#']
# ['java', 'c++', 'performance', 'visual-c++']
# ['java', 'c++', 'performance', 'visual-c++']
# ['python', 'pandas']
# ['python', 'pandas']
# ['html', 'css']
# ['html', 'css']
# ['ios', 'ios', 'ipados', 'ios-darkmode']
# ['ios', 'ipados', 'ios-darkmode']
# ['swift', 'swiftui', 'swift']
# ['swift', 'swiftui']
# ['xcode', 'realm']
# ['xcode', 'realm']
# ['javascript', 'function', 'iife']
# ['javascript', 'function', 'iife']
# ['java', 'spring', 'eclipse', 'maven', 'spring-boot']
# ['java', 'spring', 'eclipse', 'maven', 'spring-boot']
# ['c++', 'templates', 'floating-point', 'iterator', 'c++']
# ['c++', 'templates', 'floating-point', 'iterator']
# ['c++', 'assignment-operator']
# ['c++', 'assignment-operator']
# ['arrays', 'algorithm']
# ['arrays', 'algorithm']
# ['c++', 'pointers', 'initialization', 'language-lawyer']
# ['c++', 'pointers', 'initialization', 'language-lawyer']
# ['c++']
# ['c++']
# ['coq', 'agda', 'type-theory']
# ['coq', 'agda', 'type-theory']
# ['java', 'android', 'java-native-interface', 'unsatisfiedlinkerror', 'android-app-bundle']
# ['java', 'android', 'java-native-interface', 'unsatisfiedlinkerror', 'android-app-bundle']
# ['javascript', 'react-native']
# ['javascript', 'react-native']
# ['rust', 'future']
# ['rust', 'future']
# ['ionic-framework', 'npm']
# ['ionic-framework', 'npm']
# ['sql', 'sql-server']
# ['sql', 'sql-server']
# ['c#', 'swagger-ui', 'swashbuckle']
# ...
# ['android', 'android-alertdialog']
# ['css', 'css-selectors', 'css']
# ['css', 'css-selectors']
# ['git', 'tortoisegit', 'msysgit']
# ['git', 'tortoisegit', 'msysgit']
# ['android', 'android-image', 'android-gallery']
# ['android', 'android-image', 'android-gallery']
# ['git', 'undo', 'git-merge']
# ['git', 'undo', 'git-merge']
# ['sql', 'sql-server', 'tsql', 'select']
# ['sql', 'sql-server', 'tsql', 'select']
# ['time-complexity', 'big-o']
# ['time-complexity', 'big-o']
# ['python', 'dictionary', 'types', 'typeof']
# ['python', 'dictionary', 'types', 'typeof']
# ['search', 'vim', 'case-insensitive']
# ['search', 'vim', 'case-insensitive']
# ['security', 'password-encryption', 'password-storage']
# ['security', 'password-encryption', 'password-storage']
# ['comments', 'yaml']
# ['comments', 'yaml']
# ['http', 'http-status-codes']
# ['http', 'http-status-codes']
# ['javascript', 'node.js']
# ['javascript', 'node.js']
# ['python', 'string', 'random']
# ['python', 'string', 'random']
# ['c++', 'virtual-functions']
# ['c++', 'virtual-functions']
# ['string', 'bash', 'shell', 'uppercase', 'lowercase']
# ['string', 'bash', 'shell', 'uppercase', 'lowercase']
# ['git', 'git-checkout']
# ['git', 'git-checkout']
# ['git']
# ['git']
# ['bash', 'grep', 'stdout', 'pipe', 'stderr']
# ['bash', 'grep', 'stdout', 'pipe', 'stderr']
# ['string', 'bash']
# ['string', 'bash']
# ['java', 'unit-testing', 'mocking', 'mockito', 'void']
# ['java', 'unit-testing', 'mocking', 'mockito', 'void']
# ['java', 'android', 'memory', 'memory-management']
# ['java', 'android', 'memory', 'memory-management']
# ['unicode', 'utf', 'character-encoding', 'byte-order-mark']
# ['unicode', 'utf', 'character-encoding', 'byte-order-mark']
# ['javascript', 'substring', 'slice', 'substr']
# ['javascript', 'substring', 'slice', 'substr']
# ['git', 'version-control', 'git-reset', 'git-revert']
# ['git', 'version-control', 'git-reset', 'git-revert']
# ['javascript', 'jquery', 'ajax', 'post', 'file-upload']
# ['javascript', 'jquery', 'ajax', 'post', 'file-upload']
# ['python', 'python-import']
# ['python', 'python-import']
# ['git']
# ['git']
# ['css', 'organization']
# ['css', 'organization']
# ['git', 'windows-xp', 'copy-paste', 'msysgit']
# ['git', 'windows-xp', 'copy-paste', 'msysgit']
# ['eclipse', 'tabs', 'hotkeys']
# ['eclipse', 'tabs', 'hotkeys']
# ['android', 'android-layout', 'fonts']
# ['android', 'android-layout', 'fonts']
# ['git', 'rename', 'mv']
# ['git', 'rename', 'mv']
# ['c#', '.net', 'string', 'split']
# ['c#', '.net', 'string', 'split']
# ['android', 'xml', 'user-interface', 'android-layout']
# ['android', 'xml', 'user-interface', 'android-layout']
# ['php', 'wordpress', 'directory']
# ['php', 'wordpress', 'directory']
# ['android', 'android-permissions']
# ['android', 'android-permissions']
# ['json', 'string', 'syntax', 'multiline']
# ['json', 'string', 'syntax', 'multiline']
# ['javascript', 'node.js', 'node-cluster']
# ['javascript', 'node.js', 'node-cluster']
# ['javascript', 'function', 'bind']
# ['javascript', 'function', 'bind']
# ['c++', 'vector', 'stl', 'initialization']
# ['c++', 'vector', 'stl', 'initialization']
# ['javascript', 'jquery']
# ['javascript', 'jquery']
# ['image', 'svg', 'png', 'jpeg', 'gif']
# ['image', 'svg', 'png', 'jpeg', 'gif']
# ['jquery', 'html', 'jquery-ui', 'checked']
# ['jquery', 'html', 'jquery-ui', 'checked']
# ['jquery', 'google-maps', 'google-maps-api', 'jquery-plugins']
# ['jquery', 'google-maps', 'google-maps-api', 'jquery-plugins']
# ['java', 'hibernate', 'orm']
# ['java', 'hibernate', 'orm']
# ['java', 'list', 'interface', 'decoupling']
# ['java', 'list', 'interface', 'decoupling']
# ['c++', 'c', 'segmentation-fault']
# ['c++', 'c', 'segmentation-fault']
# ['javascript', 'isset']
# ['javascript', 'isset']
# ['java', '.net', 'exception']
# ['java', '.net', 'exception']
# ['php', 'apache', 'server-variables']
# ['php', 'apache', 'server-variables']
# ['java', 'static', 'overriding', 'static-methods']
# ['java', 'static', 'overriding', 'static-methods']
# ['java', 'string', 'substring']
# ['java', 'string', 'substring']
# ['c++', 'c', 'undefined-behavior', 'unspecified-behavior', 'implementation-defined-behavior']
# ['c++', 'c', 'undefined-behavior', 'unspecified-behavior', 'implementation-defined-behavior']
# ['bash', 'shell', 'syntax', 'sh', 'variable-assignment']
# ['bash', 'shell', 'syntax', 'sh', 'variable-assignment']
# ['python', 'string']
# ['python', 'string']
# ['java', 'sql', 'datetime', 'date', 'jdbc']
# ['java', 'sql', 'datetime', 'date', 'jdbc']
# ['git', 'rebase', 'git-filter-branch']
# ['git', 'rebase', 'git-filter-branch']
# ['regex', 'regex-greedy', 'non-greedy']
# ['regex', 'regex-greedy', 'non-greedy']
# ['ruby-on-rails', 'ruby', 'http', 'http-status-code']
# ['ruby-on-rails', 'ruby', 'http', 'http-status-code']
# ['mongodb', 'join']
# ['mongodb', 'join']
# ['java', 'c#', 'eclipse', 'folding']
# ['java', 'c#', 'eclipse', 'folding']
# ['c#', 'guid']
# ['c#', 'guid']
# ['javascript', 'internet-explorer', 'trim']
# ['javascript', 'internet-explorer', 'trim']
# ['c++', 'string', 'substring']
# ['c++', 'string', 'substring']
# ['git', 'putty', 'keychain', 'ssh-keys', 'pageant']
# ['git', 'putty', 'keychain', 'ssh-keys', 'pageant']
# ['python', 'floating-point', 'integer', 'rounding', 'python']
# ['python', 'floating-point', 'integer', 'rounding']
# ['llvm']
# ['llvm']
# ['.net', 'garbage-collection']
# ['.net', 'garbage-collection']
# ['solr', 'lucene', 'elasticsearch', 'sphinx', 'xapian']
# ['solr', 'lucene', 'elasticsearch', 'sphinx', 'xapian']
# ['android', 'testing', 'android-emulator', 'geolocation']
# ['android', 'testing', 'android-emulator', 'geolocation']
# ['scala', 'functional-programming', 'case-class']
# ['scala', 'functional-programming', 'case-class']
# ['android', 'android-listview', 'refresh']
# ['android', 'android-listview', 'refresh']
# ['c++', 'string', 'stl', 'formatting']
# ['c++', 'string', 'stl', 'formatting']
# ['javascript', 'string', 'replace']
# ['javascript', 'string', 'replace']
# ['python', 'dynamic', 'eval', 'exec']
# ['python', 'dynamic', 'eval', 'exec']
# ['javascript', 'jquery']
# ['javascript', 'jquery']
# ['visual-studio', 'visual-studio', 'keyboard-shortcuts']
# ['visual-studio', 'keyboard-shortcuts']
# ['javascript', 'desktop', 'google-chrome', 'notifications']
# ['javascript', 'desktop', 'google-chrome', 'notifications']
# ['concurrency', 'locking', 'mutex', 'semaphore']
# ['concurrency', 'locking', 'mutex', 'semaphore']
# ['android', 'android-listview']
# ['android', 'android-listview']
# ['c++', 'c', 'floating-point', 'precision']
# ['c++', 'c', 'floating-point', 'precision']
# ['c#', '.net', 'list', 'generics', 'arraylist']
# ['c#', '.net', 'list', 'generics', 'arraylist']
# ['android', 'android-tablelayout']
# ['android', 'android-tablelayout']
# ['javascript', 'jquery', 'forms']
# ['javascript', 'jquery', 'forms']
# ['ruby', 'code-formatting']
# ['ruby', 'code-formatting']
# ['unicode', 'encoding', 'utf', 'utf']
# ['unicode', 'encoding', 'utf']
# ['javascript', 'jquery', 'json', 'arrays']
# ['javascript', 'jquery', 'json', 'arrays']
# ['git', 'commit', 'patch']
# ['git', 'commit', 'patch']
# ['regex']
# ['regex']
# ['java', 'equals', 'hashcode']
# ['java', 'equals', 'hashcode']
# ['java', 'json', 'comparison', 'gson', 'jackson']
# ['java', 'json', 'comparison', 'gson', 'jackson']
# ['django']
# ['django']
# ['git']
# ['git']
# ['javascript', 'jquery', 'variables', 'properties', 'object-literal']
# ['javascript', 'jquery', 'variables', 'properties', 'object-literal']
# ['r', 'whitespace', 'trim', 'removing-whitespace', 'r-faq']
# ['r', 'whitespace', 'trim', 'removing-whitespace', 'r-faq']
# ['sql-server', 'tsql', 'ssms']
# ['sql-server', 'tsql', 'ssms']
# ['sql-server', 'tsql', 'aggregate-functions', 'window-functions']
# ['sql-server', 'tsql', 'aggregate-functions', 'window-functions']
# ['.net', 'iis']
# ['.net', 'iis']
# ['design-patterns', 'dependency-injection']
# ['design-patterns', 'dependency-injection']
# ['python', 'class', 'inheritance', 'constructor', 'superclass']
# ['python', 'class', 'inheritance', 'constructor', 'superclass']
# ['git']
# ['git']
# ['c#', 'asp.net', 'wcf', 'debugging', 'iis']
# ['c#', 'asp.net', 'wcf', 'debugging', 'iis']
# ['javascript', 'properties', 'object']
# ['javascript', 'properties', 'object']
# ['android', 'android-layout', 'user-interface', 'dimension', 'units-of-measurement']
# ['android', 'android-layout', 'user-interface', 'dimension', 'units-of-measurement']
# ['flash', 'caching', 'flash-cs']
# ['flash', 'caching', 'flash-cs']
# ['php', 'curl', 'youtube', 'youtube-api', 'youtube-data-api']
# ['php', 'curl', 'youtube', 'youtube-api', 'youtube-data-api']
# ['css', 'padding', 'margin']
# ['css', 'padding', 'margin']
# ['python', 'exception']
# ['python', 'exception']
# ['javascript', 'json', 'jsonp', 'terminology']
# ['javascript', 'json', 'jsonp', 'terminology']
# ['android', 'eclipse', 'certificate']
# ['android', 'eclipse', 'certificate']
# ['git', 'git-rm']
# ['git', 'git-rm']
# ['makefile', 'phony-target']
# ['makefile', 'phony-target']
# ['favicon']
# ['favicon']
# ['c#', '.net', 'visual-studio', 'debugging', 'breakpoints']
# ['c#', '.net', 'visual-studio', 'debugging', 'breakpoints']
# ['android', 'android-intent', 'android-activity']
# ['android', 'android-intent', 'android-activity']
# ['android', 'url', 'android-intent', 'android-browser']
# ['android', 'url', 'android-intent', 'android-browser']
# ['android']
# ['android']
# ['javascript', 'jquery', 'checkbox']
# ['javascript', 'jquery', 'checkbox']
# ['git', 'visual-studio', 'visual-studio', 'gitignore']
# ['git', 'visual-studio', 'gitignore']
# ['ruby-on-rails', 'ruby', 'url']
# ['ruby-on-rails', 'ruby', 'url']
# ['android', 'android-dialog']
# ['android', 'android-dialog']
# ['javascript', 'string']
# ['javascript', 'string']
# ['git', 'config']
# ['git', 'config']
# ['javascript', 'html', 'canvas', 'html-canvas', 'composite']
# ['javascript', 'html', 'canvas', 'html-canvas', 'composite']
# ['android', 'android-activity', 'transparent']
# ['android', 'android-activity', 'transparent']
# ['html', 'css']
# ['html', 'css']
# ['android', 'android-intent', 'android-activity']
# ['android', 'android-intent', 'android-activity']
# ['mysql', 'text', 'messages', 'varchar']
# ['mysql', 'text', 'messages', 'varchar']
# ['java', 'jsp', 'jsf', 'servlets', 'java-ee']
# ['java', 'jsp', 'jsf', 'servlets', 'java-ee']
# ['java', 'multithreading']
# ['java', 'multithreading']
# ['oop', 'functional-programming', 'paradigms']
# ['oop', 'functional-programming', 'paradigms']
# ['cgi']
# ['cgi']
# ['android', 'html', 'xml-parsing', 'textview']
# ['android', 'html', 'xml-parsing', 'textview']
# ['sql', 'sql-server', 'tsql', 'sql-server']
# ['sql', 'sql-server', 'tsql']
# ['java', 'collections', 'constructor', 'initialization', 'hashset']
# ['java', 'collections', 'constructor', 'initialization', 'hashset']
# ['python', 'file']
# ['python', 'file']
# ['string', 'bash', 'comparison']
# ['string', 'bash', 'comparison']
# ['python', 'path', 'filesystems', 'glob', 'fnmatch']
# ['python', 'path', 'filesystems', 'glob', 'fnmatch']
# ['dictionary', 'go', 'go-map']
# ['dictionary', 'go', 'go-map']
# ['windows', 'powershell', 'scripting']
# ['windows', 'powershell', 'scripting']
# ['c#', '.net', 'methods', 'delegates']
# ['c#', '.net', 'methods', 'delegates']
# ['git', 'version-control', 'git-rebase', 'git-rewrite-history']
# ['git', 'version-control', 'git-rebase', 'git-rewrite-history']
# ['bash', 'syntax']
# ['bash', 'syntax']
# ['java', 'date', 'iso']
# ['java', 'date', 'iso']
# ['javascript', 'jquery', 'referenceerror']
# ['javascript', 'jquery', 'referenceerror']
# ['javascript', 'string', 'replace']
# ['javascript', 'string', 'replace']
# ['ios', 'objective-c', 'nsnotificationcenter']
# ['ios', 'objective-c', 'nsnotificationcenter']
# ['python', 'unicode', 'python', 'rawstring']
# ['python', 'unicode', 'rawstring']
# ['php', 'string', 'spaces']
# ['php', 'string', 'spaces']
# ['sql', 'sql-order-by']
# ['sql', 'sql-order-by']
# ['php', 'datetime']
# ['php', 'datetime']
# ['forms', 'email', 'email-validation', 'email-address']
# ['forms', 'email', 'email-validation', 'email-address']
# ['git']
# ['git']
# ['git', 'version-control', 'git-clone', 'git-bare', 'git-non-bare-repository']
# ['git', 'version-control', 'git-clone', 'git-bare', 'git-non-bare-repository']
# ['javascript', 'html', 'css']
# ['javascript', 'html', 'css']
# ['c#', 'entity-framework', 'transactions', 'inversion-of-control']
# ['c#', 'entity-framework', 'transactions', 'inversion-of-control']
# ['c#', 'wpf', 'colors', 'hex']
# ['c#', 'wpf', 'colors', 'hex']
# ['java', 'jvm', 'java-native-interface', '-bit', '-bit']
# ['java', 'jvm', 'java-native-interface', '-bit']
# ['jquery', 'httprequest', 'put']
# ['jquery', 'httprequest', 'put']
# ['ruby-on-rails', 'ruby', 'exception', 'exception-handling', 'error-handling']
# ['ruby-on-rails', 'ruby', 'exception', 'exception-handling', 'error-handling']
# ['javascript', 'function', 'arguments', 'argument-passing']
# ['javascript', 'function', 'arguments', 'argument-passing']
# ['logging', 'logrotate']
# ['logging', 'logrotate']
# ['android', 'email']
# ['android', 'email']
# ['html', 'css', 'image']
# ['html', 'css', 'image']
# ['javascript', 'jquery', 'jquery-plugins', 'timer']
# ['javascript', 'jquery', 'jquery-plugins', 'timer']
# ['android', 'visibility', 'android-softkeyboard']
# ['android', 'visibility', 'android-softkeyboard']
# ['python', 'egg']
# ['python', 'egg']
# ['php']
# ['php']
# ['macos', 'shell', 'buffer', 'clear']
# ['macos', 'shell', 'buffer', 'clear']
# ['logging']
# ['logging']
# ['powershell', 'command-line-arguments']
# ['powershell', 'command-line-arguments']
# ['javascript', 'jquery', 'radio-button', 'dynamic-forms']
# ['javascript', 'jquery', 'radio-button', 'dynamic-forms']
# ['javascript', 'jquery', 'asp.net-mvc']
# ['javascript', 'jquery', 'asp.net-mvc']
# ['c++', 'templates', 'keyword']
# ['c++', 'templates', 'keyword']
# ['objective-c', 'xcode', 'xcode', 'nszombie']
# ['objective-c', 'xcode', 'nszombie']
# ['php', 'http', 'curl', 'http-post']
# ['php', 'http', 'curl', 'http-post']
# ['.net', '-bit', 'pinvoke', '-bit', 'badimageformatexception']
# ['.net', '-bit', 'pinvoke', 'badimageformatexception']
# ['api', 'compiler-construction', 'binary', 'operating-system', 'abi']
# ['api', 'compiler-construction', 'binary', 'operating-system', 'abi']
# ['php', 'arrays']
# ['php', 'arrays']
# ['java', 'maven', 'mvn-repo']
# ['java', 'maven', 'mvn-repo']
# ['android', 'coding-style']
# ['android', 'coding-style']
# ['c#', 'reflection']
# ['c#', 'reflection']
# ['python', 'list', 'optimization', 'nested-lists', 'flatten']
# ['python', 'list', 'optimization', 'nested-lists', 'flatten']
# ['go', 'overloading']
# ['go', 'overloading']
# ['javascript', 'html', 'hyperlink']
# ['javascript', 'html', 'hyperlink']
# ['c++', 'iterator', 'coding-style']
# ['c++', 'iterator', 'coding-style']
# ['android', 'email']
# ['android', 'email']
# ['android', 'exception', 'android-manifest']
# ['android', 'exception', 'android-manifest']
# ['c#', 'debugging', 'release', 'compiler-directives']
# ['c#', 'debugging', 'release', 'compiler-directives']
# ['c#', 'jit']
# ['c#', 'jit']
# ['visual-studio']
# ['visual-studio']
# ['git']
# ['git']
# ['javascript', 'string', 'optimization', 'comparison', 'binary-search']
# ['javascript', 'string', 'optimization', 'comparison', 'binary-search']
# ['c#', '.net', 'bytearray', 'binary-data']
# ['c#', '.net', 'bytearray', 'binary-data']
# ['javascript', 'jquery', 'date', 'jquery-ui', 'jquery-ui-datepicker']
# ['javascript', 'jquery', 'date', 'jquery-ui', 'jquery-ui-datepicker']
# ['sql', 'mysql', 'greatest-n-per-group', 'ranking']
# ['sql', 'mysql', 'greatest-n-per-group', 'ranking']
# ['git', 'git-rm']
# ['git', 'git-rm']
# ['android', 'string', 'layout']
# ['android', 'string', 'layout']
# ['uitableview', 'cocoa-touch', 'uikit', 'didselectrowatindexpath']
# ['uitableview', 'cocoa-touch', 'uikit', 'didselectrowatindexpath']
# ['c#', 'casting', 'type-conversion']
# ['c#', 'casting', 'type-conversion']
# ['python', 'math', 'optimization', 'primes']
# ['python', 'math', 'optimization', 'primes']
# ['c++', 'performance', 'dictionary', 'unordered-map']
# ['c++', 'performance', 'dictionary', 'unordered-map']
# ['python', 'django', 'django-models']
# ['python', 'django', 'django-models']
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print("Number of nodes: ",len(list(network.nodes)))
print("Number of edges: ", len(network.edges))
# Out:
# Number of nodes:  4689
# Number of edges:  27615

# %% [markdown]
# Since this is quite a few nodes and edges we simplify it to show the most important features.

# %%
multiTagDict = {}
for tag in tagDict:
    # Only use nodes that appear more than 6 times.
    if tagDict[tag] > 6:
        multiTagDict[tag] = tagDict[tag]

# %%
networkSmall = nx.Graph()
networkSmall.add_nodes_from(list(dict.fromkeys(multiTagDict)))
print("Number of nodes: ", len(list(networkSmall.nodes)))
# Out:
# Number of nodes:  754

# %%
# Because we have to work on each questions tag-list, we have to use the saved jsons.
for json in jsons:
    for question in json['items']:
        # trimming of tags
        taglisthelper = [re.sub(r"(-)*(\d)+(\..)*","",tag) for tag in question['tags']]
        # remove duplicates
        taglisthelper = list(dict.fromkeys(taglisthelper))
        for tag in taglisthelper:
            if tag in multiTagDict:
                for tag2 in taglisthelper:
                    if tag2 in multiTagDict:
                        networkSmall.add_edge(tag,tag2)
print("Number of edges: ", len(networkSmall.edges))
# Out:
# Number of edges:  9018

# %% [markdown]
# Now we boiled it down to 750 nodes. And may see a prettier network.
# We still do calculations on the large network, for better results.

# %%
# helper function for scaling nodesize
def rescale(val, in_min, in_max, out_min, out_max):
    return out_min + (val - in_min) * ((out_max - out_min) / (in_max - in_min))

# %%
plt.figure(figsize=(20,10))

forceatlas2Small = ForceAtlas2(
                        # Behavior alternatives
                        outboundAttractionDistribution=False,  # Dissuade hubs
                        linLogMode=False,  # NOT IMPLEMENTED
                        adjustSizes=False,  # Prevent overlap (NOT IMPLEMENTED)
                        edgeWeightInfluence=1.0,

                        # Performance
                        jitterTolerance=1.0,  # Tolerance
                        barnesHutOptimize=True,
                        barnesHutTheta=1.2,
                        multiThreaded=False,  # NOT IMPLEMENTED

                        # Tuning
                        scalingRatio=2.0,
                        strongGravityMode=False,
                        gravity=1.0,

                        # Log
                        verbose=True)
# Degree dictionary
degreeDict = dict(networkSmall.degree)
# The 25 largest nodes based on degree (needed for labels)
largestnodesSmall = dict(sorted(dict(networkSmall.degree()).items(), key=lambda item: item[1], reverse=True)[0:25])
# Label dictionary
nodelabelsSmall = {}
for key, value in largestnodesSmall.items():
    nodelabelsSmall[key] = key

# Positions on network
positionsSmall = forceatlas2Small.forceatlas2_networkx_layout(networkSmall, pos=None, iterations=4000)
# Draw nodes
nx.draw_networkx_nodes(networkSmall, positionsSmall, node_size=[rescale(v,2,650,15,5000) for v in degreeDict.values()], with_labels=False, node_color="blue", alpha=0.4)
# Draw edges
nx.draw_networkx_edges(networkSmall, positionsSmall, edge_color="green", alpha=0.05)
# Draw labels
labels = nx.draw_networkx_labels(networkSmall, positionsSmall, labels=nodelabelsSmall, font_color='k', font_size=16, font_weight='normal')

plt.axis('off')
plt.show()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 4000/4000 [00:50<00:00, 79.61it/s]
# BarnesHut Approximation  took  6.96  seconds
# Repulsion forces  took  40.58  seconds
# Gravitational forces  took  0.25  seconds
# Attraction forces  took  0.44  seconds
# AdjustSpeedAndApplyForces step  took  1.03  seconds
# C:\Users\mads_\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %% [markdown]
# There are some clear correlations between certain tag groups, for example the group at the top of the network. This group contains angular, css, html and jquery. All are highly related to frontend and web development.
#
# Meanwhile a group of swift, ios, macos, xcode and linux have assembled on the right side. It seems Apple is such an important player in the world, that even our Stack Overflow network is affected by a single company. Linux has has snuck in there most as macos are both operating systems, and very similar to each other when compared to an OS like Microsoft.
#
# Performance computing has a group at the bottom with C, C++, string and performance. C++ and C are often used for high performance computing (HPC), but string has most likely to do with strings in C and C++ being problematic to most newcommers of the languages.

# %%
degree_sequence = sorted([d for n, d in network.degree()], reverse=True)  # degree sequence
# print "Degree sequence", degree_sequence
degreeCount = Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())

#plt.figure(figsize=(20,10))
#ax = plt.subplot()
fig, ax = plt.subplots(figsize=(15,8))

plt.bar(deg, cnt, width=0.80, color='b')



plt.title("Degree Histogram")
plt.ylabel("Count")
plt.xlabel("Degree")

plt.show()

# %% [markdown]
# Based on the degree distribution, we can see that almost all tags have below 40 connections. So let's zoom in a bit.

# %%
above40count=0
totalcount=0
for k,v in degreeCount.items():
    #print(k)
    #print(v)
    totalcount+=v
    if k > 40:
        above40count+=v
print("Total above 40: ", above40count)
print("Percentage of all nodes: ", above40count/totalcount*100)
print("We will have" ,100 - (above40count/totalcount*100), "percent shown")
# Out:
# Total above 40:  169
# Percentage of all nodes:  3.604179995734698
# We will have 96.3958200042653 percent shown

# %%
degree_sequence = sorted([d for n, d in network.degree() if d < 40], reverse=True)  # degree sequence

degreeCount = Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())

fig, ax = plt.subplots(figsize=(15,8))

plt.bar(deg, cnt, width=0.80, color='b')

plt.title("Degree Histogram")
plt.ylabel("Count")
plt.xlabel("Degree")

plt.show()

# %% [markdown]
# It's very clear that most subject are only connected to approximately 5 or 6 other subjects. This could indicate that subjects on Stack Overflow are very secluded, and question are generally very specific. However it could also mean that a lot of programming subject do not share very many of the same problems. A language like C which has troublesome Strings (atleast for new programmers), does not share string issues with Java - a language which has simple String objects.
